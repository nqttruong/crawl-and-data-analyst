# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\dienthoai_maytinhbang\dienthoaiphothong"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dtphothong_all.ipynb',
#  'tk_dtpt_Forme.csv',
#  'tk_dtpt_Itel.csv',
#  'tk_dtpt_Massel.csv',
#  'tk_dtpt_Masstel.csv',
#  'tk_dtpt_Masstel_t2.csv',
#  'tk_dtpt_Mobell.csv',
#  'tk_dtpt_Nokia.csv',
#  'tk_dtpt_Vtel.csv',
#  'tk_mds.ipynb',
#  'tk_mtb - Copy (2).ipynb',
#  'tk_mtb - Copy (3).ipynb',
#  'tk_mtb - Copy (4).ipynb',
#  'tk_mtb - Copy.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dtphothong_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Điện thoại di động Forme N82 4G - Hàng chính hãng  531.000₫
# 1             Điện Thoại Forme D888 - Hàng Chính Hãng  531.000₫
# 2   Điện Thoại Di Động Forme D111 4G - Hàng Chính ...  413.100₫
# 3   Điện Thoại Di Động Forme D999 4G - Hàng Chính ...  760.000₫
# 4   Điện thoại di động Forme Q8 (4G) - Hàng chính ...  539.100₫
# ..                                                ...       ...
# 17      Điện thoại Nokia 105 4G Pro - Hàng chính hãng  680.000₫
# 18  Điện thoại di động Nokia 105 4G - Hàng chính hãng  750.500₫
# 19         Điện thoại Nokia N110 4G - Hàng chính hãng  809.100₫
# 0    Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  309.000₫
# 1    Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  301.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/dien-thoai-di-dong-forme-n82-4...      1     -10%
# 1   https://tiki.vn/dien-thoai-forme-d888-hang-chi...      2     -24%
# 2   https://tiki.vn/dien-thoai-di-dong-forme-d111-...      3     -10%
# 3   https://tiki.vn/dien-thoai-di-dong-forme-d999-...      4     -10%
# 4   https://tiki.vn/dien-thoai-di-dong-forme-q8-4g...      5     -13%
# ..                                                ...    ...      ...
# 17  https://tiki.vn/dien-thoai-nokia-105-4g-pro-ha...     18      NaN
# 18  https://tiki.vn/dien-thoai-di-dong-nokia-105-4...     19      NaN
# 19  https://tiki.vn/dien-thoai-nokia-110-4g-chinh-...     20      NaN
# 0   https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...      1     -23%
# 1   https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...      2     -25%
#
#          sales  brand
# 0          NaN  Forme
# 1     Đã bán 5  Forme
# 2     Đã bán 2  Forme
# 3          NaN  Forme
# 4          NaN  Forme
# ..         ...    ...
# 17    Đã bán 2  Nokia
# 18    Đã bán 1  Nokia
# 19         NaN  Nokia
# 0   Đã bán 138   Vtel
# 1    Đã bán 98   Vtel
#
# [90 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all["category"] = "dienthoaiphothong"
df_all = df_all.reset_index(drop=True)
df_all = df_all.drop('index', axis=1)

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Điện thoại di động Forme N82 4G - Hàng chính hãng  531.000₫
# 1             Điện Thoại Forme D888 - Hàng Chính Hãng  531.000₫
# 2   Điện Thoại Di Động Forme D111 4G - Hàng Chính ...  413.100₫
# 3   Điện Thoại Di Động Forme D999 4G - Hàng Chính ...  760.000₫
# 4   Điện thoại di động Forme Q8 (4G) - Hàng chính ...  539.100₫
# ..                                                ...       ...
# 85      Điện thoại Nokia 105 4G Pro - Hàng chính hãng  680.000₫
# 86  Điện thoại di động Nokia 105 4G - Hàng chính hãng  750.500₫
# 87         Điện thoại Nokia N110 4G - Hàng chính hãng  809.100₫
# 88   Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  309.000₫
# 89   Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  301.000₫
#
#                                             link_item discount       sales  \
# 0   https://tiki.vn/dien-thoai-di-dong-forme-n82-4...     -10%         NaN
# 1   https://tiki.vn/dien-thoai-forme-d888-hang-chi...     -24%    Đã bán 5
# 2   https://tiki.vn/dien-thoai-di-dong-forme-d111-...     -10%    Đã bán 2
# 3   https://tiki.vn/dien-thoai-di-dong-forme-d999-...     -10%         NaN
# 4   https://tiki.vn/dien-thoai-di-dong-forme-q8-4g...     -13%         NaN
# ..                                                ...      ...         ...
# 85  https://tiki.vn/dien-thoai-nokia-105-4g-pro-ha...      NaN    Đã bán 2
# 86  https://tiki.vn/dien-thoai-di-dong-nokia-105-4...      NaN    Đã bán 1
# 87  https://tiki.vn/dien-thoai-nokia-110-4g-chinh-...      NaN         NaN
# 88  https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...     -23%  Đã bán 138
# 89  https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...     -25%   Đã bán 98
#
#     brand           category
# 0   Forme  dienthoaiphothong
# 1   Forme  dienthoaiphothong
# 2   Forme  dienthoaiphothong
# 3   Forme  dienthoaiphothong
# 4   Forme  dienthoaiphothong
# ..    ...                ...
# 85  Nokia  dienthoaiphothong
# 86  Nokia  dienthoaiphothong
# 87  Nokia  dienthoaiphothong
# 88   Vtel  dienthoaiphothong
# 89   Vtel  dienthoaiphothong
#
# [90 rows x 7 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0     531000
# 1     531000
# 2     413100
# 3     760000
# 4     539100
#        ...
# 85    680000
# 86    750500
# 87    809100
# 88    309000
# 89    301000
# Name: price, Length: 90, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       NaN
# 1       5.0
# 2       2.0
# 3       NaN
# 4       NaN
#       ...
# 85      2.0
# 86      1.0
# 87      NaN
# 88    138.0
# 89     98.0
# Name: sales, Length: 90, dtype: float64

# %%
df_all
# Out:
#                                                 title   price  \
# 0   Điện thoại di động Forme N82 4G - Hàng chính hãng  531000
# 1             Điện Thoại Forme D888 - Hàng Chính Hãng  531000
# 2   Điện Thoại Di Động Forme D111 4G - Hàng Chính ...  413100
# 3   Điện Thoại Di Động Forme D999 4G - Hàng Chính ...  760000
# 4   Điện thoại di động Forme Q8 (4G) - Hàng chính ...  539100
# ..                                                ...     ...
# 85      Điện thoại Nokia 105 4G Pro - Hàng chính hãng  680000
# 86  Điện thoại di động Nokia 105 4G - Hàng chính hãng  750500
# 87         Điện thoại Nokia N110 4G - Hàng chính hãng  809100
# 88   Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  309000
# 89   Điện thoại di động Vtel E10 4G – Hàng Chính Hãng  301000
#
#                                             link_item discount  sales  brand  \
# 0   https://tiki.vn/dien-thoai-di-dong-forme-n82-4...     -10%    NaN  Forme
# 1   https://tiki.vn/dien-thoai-forme-d888-hang-chi...     -24%    5.0  Forme
# 2   https://tiki.vn/dien-thoai-di-dong-forme-d111-...     -10%    2.0  Forme
# 3   https://tiki.vn/dien-thoai-di-dong-forme-d999-...     -10%    NaN  Forme
# 4   https://tiki.vn/dien-thoai-di-dong-forme-q8-4g...     -13%    NaN  Forme
# ..                                                ...      ...    ...    ...
# 85  https://tiki.vn/dien-thoai-nokia-105-4g-pro-ha...      NaN    2.0  Nokia
# 86  https://tiki.vn/dien-thoai-di-dong-nokia-105-4...      NaN    1.0  Nokia
# 87  https://tiki.vn/dien-thoai-nokia-110-4g-chinh-...      NaN    NaN  Nokia
# 88  https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...     -23%  138.0   Vtel
# 89  https://tiki.vn/dien-thoai-di-dong-vtel-e10-4g...     -25%   98.0   Vtel
#
#              category
# 0   dienthoaiphothong
# 1   dienthoaiphothong
# 2   dienthoaiphothong
# 3   dienthoaiphothong
# 4   dienthoaiphothong
# ..                ...
# 85  dienthoaiphothong
# 86  dienthoaiphothong
# 87  dienthoaiphothong
# 88  dienthoaiphothong
# 89  dienthoaiphothong
#
# [90 rows x 7 columns]

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0            NaN
# 1      2655000.0
# 2       826200.0
# 3            NaN
# 4            NaN
#          ...
# 85     1360000.0
# 86      750500.0
# 87           NaN
# 88    42642000.0
# 89    29498000.0
# Name: revenue, Length: 90, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số điện thoại phổ thông: ", total)
# Out:
# Tổng doanh số điện thoại phổ thông:  662174966.0

# %%
df_all.to_csv("tk_dtphothong_all_ed.csv")
