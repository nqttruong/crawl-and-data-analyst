# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\dienthoai_maytinhbang\dienthoaiban"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dtb_Alcatel.csv',
#  'tk_dtb_China Mobile.csv',
#  'tk_dtb_Cisco.csv',
#  'tk_dtb_Fanvil.csv',
#  'tk_dtb_Flyingvoice.csv',
#  'tk_dtb_Grandstream.csv',
#  'tk_dtb_HP.csv',
#  'tk_dtb_Huawei.csv',
#  'tk_dtb_KTEL.csv',
#  'tk_dtb_Panasonic.csv',
#  'tk_dtb_Uniden.csv',
#  'tk_dtb_Yealink.csv',
#  'tk_dtpt_Panasonic_t2.csv',
#  'tk_dtsmartphone_all.ipynb',
#  'tk_mds.ipynb',
#  'tk_mtb - Copy (2).ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dtban_all.csv", index="False")

# %%
df_all.head()
# Out:
#                                                title       price  \
# 0  (Hàng chính hãng) Điện thoại bàn hữu tuyến H2P...  2.220.000₫
# 0  Điện Thoại Bàn Homephone lắp sim - Lắp Tất Cả ...    650.000₫
# 0      Điện thoại Ip phone Cisco CP-7945G chính hãng  4.500.000₫
# 1     Cisco Unified IP Phone 7962G - Hàng chính hãng  4.900.000₫
# 2  Cisco Unified IP Phone CP-7821-K9 - Hàng chính...  2.580.000₫
#
#                                            link_item  index discount  \
# 0  https://tiki.vn/dien-thoai-ban-huu-tuyen-h2p-h...      1      NaN
# 0  https://tiki.vn/dien-thoai-ban-homephone-lap-s...      1      NaN
# 0  https://tiki.vn/dien-thoai-ip-phone-cisco-cp-7...      1      NaN
# 1  https://tiki.vn/cisco-unified-ip-phone-7962g-h...      2      NaN
# 2  https://tiki.vn/cisco-unified-ip-phone-cp-7821...      3      NaN
#
#        sales         brand
# 0        NaN       Alcatel
# 0  Đã bán 58  China Mobile
# 0        NaN         Cisco
# 1        NaN         Cisco
# 2        NaN         Cisco

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all["category"] = "dienthoaiban"
df_all = df_all.reset_index(drop=True)
df_all = df_all.drop('index', axis=1)

# %%
df_all
# Out:
#                                                 title    price  \
# 0   (Hàng chính hãng) Điện thoại bàn hữu tuyến H2P...  2220000
# 1   Điện Thoại Bàn Homephone lắp sim - Lắp Tất Cả ...   650000
# 2       Điện thoại Ip phone Cisco CP-7945G chính hãng  4500000
# 3      Cisco Unified IP Phone 7962G - Hàng chính hãng  4900000
# 4   Cisco Unified IP Phone CP-7821-K9 - Hàng chính...  2580000
# ..                                                ...      ...
# 73         Điện thoại bàn có dây Panasonic KX-TS560MX   730000
# 74  Điện thoại để bàn Panasonic KX-TS840 hàng chín...   800000
# 75  Điện Thoại Bàn Panasonic KXTGF320CX - Hàng Chí...  2350000
# 76   Điện thoại Panasonic KX-TS560MX -Hàng chính hãng   675000
# 77  Điện thoại Panasonic KX-TGC313CX -Hàng chính hãng  1949000
#
#                                             link_item discount  sales  \
# 0   https://tiki.vn/dien-thoai-ban-huu-tuyen-h2p-h...      NaN    NaN
# 1   https://tiki.vn/dien-thoai-ban-homephone-lap-s...      NaN   58.0
# 2   https://tiki.vn/dien-thoai-ip-phone-cisco-cp-7...      NaN    NaN
# 3   https://tiki.vn/cisco-unified-ip-phone-7962g-h...      NaN    NaN
# 4   https://tiki.vn/cisco-unified-ip-phone-cp-7821...      NaN    NaN
# ..                                                ...      ...    ...
# 73  https://tiki.vn/dien-thoai-ban-co-day-panasoni...      NaN   12.0
# 74  https://tiki.vn/dien-thoai-de-ban-panasonic-kx...      NaN    NaN
# 75  https://tiki.vn/dien-thoai-ban-panasonic-kxtgf...      NaN    9.0
# 76  https://tiki.vn/dien-thoai-panasonic-kx-ts560m...      NaN    6.0
# 77  https://tiki.vn/dien-thoai-panasonic-kx-tgc313...      NaN    1.0
#
#            brand      category     revenue
# 0        Alcatel  dienthoaiban         NaN
# 1   China Mobile  dienthoaiban  37700000.0
# 2          Cisco  dienthoaiban         NaN
# 3          Cisco  dienthoaiban         NaN
# 4          Cisco  dienthoaiban         NaN
# ..           ...           ...         ...
# 73     Panasonic  dienthoaiban   8760000.0
# 74     Panasonic  dienthoaiban         NaN
# 75     Panasonic  dienthoaiban  21150000.0
# 76     Panasonic  dienthoaiban   4050000.0
# 77     Panasonic  dienthoaiban   1949000.0
#
# [78 rows x 8 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0     2220000
# 1      650000
# 2     4500000
# 3     4900000
# 4     2580000
#        ...
# 73     730000
# 74     800000
# 75    2350000
# 76     675000
# 77    1949000
# Name: price, Length: 78, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      NaN
# 1     58.0
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 73    12.0
# 74     NaN
# 75     9.0
# 76     6.0
# 77     1.0
# Name: sales, Length: 78, dtype: float64

# %%
df_all
# Out:
#                                                 title    price  \
# 0   (Hàng chính hãng) Điện thoại bàn hữu tuyến H2P...  2220000
# 1   Điện Thoại Bàn Homephone lắp sim - Lắp Tất Cả ...   650000
# 2       Điện thoại Ip phone Cisco CP-7945G chính hãng  4500000
# 3      Cisco Unified IP Phone 7962G - Hàng chính hãng  4900000
# 4   Cisco Unified IP Phone CP-7821-K9 - Hàng chính...  2580000
# ..                                                ...      ...
# 73         Điện thoại bàn có dây Panasonic KX-TS560MX   730000
# 74  Điện thoại để bàn Panasonic KX-TS840 hàng chín...   800000
# 75  Điện Thoại Bàn Panasonic KXTGF320CX - Hàng Chí...  2350000
# 76   Điện thoại Panasonic KX-TS560MX -Hàng chính hãng   675000
# 77  Điện thoại Panasonic KX-TGC313CX -Hàng chính hãng  1949000
#
#                                             link_item  index discount  sales  \
# 0   https://tiki.vn/dien-thoai-ban-huu-tuyen-h2p-h...      1      NaN    NaN
# 1   https://tiki.vn/dien-thoai-ban-homephone-lap-s...      1      NaN   58.0
# 2   https://tiki.vn/dien-thoai-ip-phone-cisco-cp-7...      1      NaN    NaN
# 3   https://tiki.vn/cisco-unified-ip-phone-7962g-h...      2      NaN    NaN
# 4   https://tiki.vn/cisco-unified-ip-phone-cp-7821...      3      NaN    NaN
# ..                                                ...    ...      ...    ...
# 73  https://tiki.vn/dien-thoai-ban-co-day-panasoni...      9      NaN   12.0
# 74  https://tiki.vn/dien-thoai-de-ban-panasonic-kx...     10      NaN    NaN
# 75  https://tiki.vn/dien-thoai-ban-panasonic-kxtgf...     11      NaN    9.0
# 76  https://tiki.vn/dien-thoai-panasonic-kx-ts560m...     12      NaN    6.0
# 77  https://tiki.vn/dien-thoai-panasonic-kx-tgc313...     13      NaN    1.0
#
#            brand      category
# 0        Alcatel  dienthoaiban
# 1   China Mobile  dienthoaiban
# 2          Cisco  dienthoaiban
# 3          Cisco  dienthoaiban
# 4          Cisco  dienthoaiban
# ..           ...           ...
# 73     Panasonic  dienthoaiban
# 74     Panasonic  dienthoaiban
# 75     Panasonic  dienthoaiban
# 76     Panasonic  dienthoaiban
# 77     Panasonic  dienthoaiban
#
# [78 rows x 8 columns]

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0            NaN
# 1     37700000.0
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 73     8760000.0
# 74           NaN
# 75    21150000.0
# 76     4050000.0
# 77     1949000.0
# Name: revenue, Length: 78, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số điện thoại bàn: ", total)
# Out:
# Tổng doanh số điện thoại bàn:  2614699000.0

# %%
df_all.to_csv("tk_dtban_all_ed.csv")
