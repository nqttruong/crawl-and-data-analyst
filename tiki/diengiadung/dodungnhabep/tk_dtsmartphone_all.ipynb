# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dtsmartphone_all.ipynb',
#  'tk_mvb_Mamamy_t10.csv',
#  'tk_mvb_Mamamy_t11.csv',
#  'tk_mvb_Mamamy_t12.csv',
#  'tk_mvb_Mamamy_t13.csv',
#  'tk_mvb_Mamamy_t14.csv',
#  'tk_mvb_Mamamy_t15.csv',
#  'tk_mvb_Mamamy_t16.csv',
#  'tk_mvb_Mamamy_t17.csv',
#  'tk_mvb_Mamamy_t18.csv',
#  'tk_mvb_Mamamy_t19.csv',
#  'tk_mvb_Mamamy_t2.csv',
#  'tk_mvb_Mamamy_t20.csv',
#  'tk_mvb_Mamamy_t21.csv',
#  'tk_mvb_Mamamy_t22.csv',
#  'tk_mvb_Mamamy_t23.csv',
#  'tk_mvb_Mamamy_t24.csv',
#  'tk_mvb_Mamamy_t25.csv',
#  'tk_mvb_Mamamy_t26.csv',
#  'tk_mvb_Mamamy_t27.csv',
#  'tk_mvb_Mamamy_t28.csv',
#  'tk_mvb_Mamamy_t29.csv',
#  'tk_mvb_Mamamy_t3.csv',
#  'tk_mvb_Mamamy_t30.csv',
#  'tk_mvb_Mamamy_t31.csv',
#  'tk_mvb_Mamamy_t32.csv',
#  'tk_mvb_Mamamy_t33.csv',
#  'tk_mvb_Mamamy_t34.csv',
#  'tk_mvb_Mamamy_t35.csv',
#  'tk_mvb_Mamamy_t36.csv',
#  'tk_mvb_Mamamy_t37.csv',
#  'tk_mvb_Mamamy_t38.csv',
#  'tk_mvb_Mamamy_t39.csv',
#  'tk_mvb_Mamamy_t4.csv',
#  'tk_mvb_Mamamy_t40.csv',
#  'tk_mvb_Mamamy_t41.csv',
#  'tk_mvb_Mamamy_t42.csv',
#  'tk_mvb_Mamamy_t43.csv',
#  'tk_mvb_Mamamy_t44.csv',
#  'tk_mvb_Mamamy_t45.csv',
#  'tk_mvb_Mamamy_t46.csv',
#  'tk_mvb_Mamamy_t47.csv',
#  'tk_mvb_Mamamy_t48.csv',
#  'tk_mvb_Mamamy_t49.csv',
#  'tk_mvb_Mamamy_t5.csv',
#  'tk_mvb_Mamamy_t50.csv',
#  'tk_mvb_Mamamy_t6.csv',
#  'tk_mvb_Mamamy_t7.csv',
#  'tk_mvb_Mamamy_t8.csv',
#  'tk_mvb_Mamamy_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all = pd.read_csv("tk_dodungnhabep_all.csv")

# %%
df_all
# Out:
#       Unnamed: 0                                              title  \
# 0              0                                  Máy xay cafe 600N
# 1              1  Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...
# 2              2  Nồi Chiên Không Dầu Magic A-802 (4.6 Lít) Đen ...
# 3              3  Máy Đánh Trứng Daewoo DWHM-354 (150W) - Hàng c...
# 4              4                                                NaN
# ...          ...                                                ...
# 1970          35                                                NaN
# 1971          36  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...
# 1972          37  Nồi điện đa năng phủ chống dính cao cấp - Nồi ...
# 1973          38  Nồi nấu chậm Panasonic NF-N31AWRA - Hàng Chính...
# 1974          39  Nồi cơm điện tử Cuckoo 1.08L CR-0675F - Tùy ch...
#
#            price                                          link_item  index  \
# 0       699.000₫  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      1
# 1     2.399.000₫  https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...      2
# 2     1.090.000₫  https://tiki.vn/noi-chien-khong-dau-magic-a-80...      3
# 3       216.000₫  https://tiki.vn/may-danh-trung-daewoo-dwhm-354...      4
# 4            NaN  https://tiki.vn/khay-silicone-danh-cho-noi-chi...      5
# ...          ...                                                ...    ...
# 1970         NaN  https://tiki.vn/lo-vi-song-trang-men-samsung-d...     36
# 1971  1.599.000₫  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...     37
# 1972    299.000₫  https://tiki.vn/noi-dien-da-nang-phu-chong-din...     38
# 1973  1.299.000₫  https://tiki.vn/noi-nau-cham-panasonic-nf-n31a...     39
# 1974  1.690.000₫  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...     40
#
#      discount        sales      category
# 0         -2%   Đã bán 199  dodungnhabep
# 1        -45%    Đã bán 25  dodungnhabep
# 2        -46%  Đã bán 1.1k  dodungnhabep
# 3         NaN  Đã bán 1.2k  dodungnhabep
# 4        -39%          NaN  dodungnhabep
# ...       ...          ...           ...
# 1970      NaN          NaN  dodungnhabep
# 1971      NaN    Đã bán 78  dodungnhabep
# 1972      NaN  Đã bán 1.1k  dodungnhabep
# 1973      NaN    Đã bán 74  dodungnhabep
# 1974      NaN   Đã bán 659  dodungnhabep
#
# [1975 rows x 8 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)
df_all = df_all.drop('Unnamed: 0', axis=1)

# %%
df_all.dropna(subset=['title'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0                                     Máy xay cafe 600N    699.000₫
# 1     Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...  2.399.000₫
# 2     Nồi Chiên Không Dầu Magic A-802 (4.6 Lít) Đen ...  1.090.000₫
# 3     Máy Đánh Trứng Daewoo DWHM-354 (150W) - Hàng c...    216.000₫
# 4     Bếp Đôi Điện Từ Hồng Ngoại Sunhouse SHB9104MT ...  2.940.000₫
# ...                                                 ...         ...
# 1624  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.150.000₫
# 1625  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1.599.000₫
# 1626  Nồi điện đa năng phủ chống dính cao cấp - Nồi ...    299.000₫
# 1627  Nồi nấu chậm Panasonic NF-N31AWRA - Hàng Chính...  1.299.000₫
# 1628  Nồi cơm điện tử Cuckoo 1.08L CR-0675F - Tùy ch...  1.690.000₫
#
#                                               link_item discount        sales  \
# 0     https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      -2%   Đã bán 199
# 1     https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...     -45%    Đã bán 25
# 2     https://tiki.vn/noi-chien-khong-dau-magic-a-80...     -46%  Đã bán 1.1k
# 3     https://tiki.vn/may-danh-trung-daewoo-dwhm-354...      NaN  Đã bán 1.2k
# 4     https://tiki.vn/bep-doi-dien-tu-hong-ngoai-sun...      -6%   Đã bán 526
# ...                                                 ...      ...          ...
# 1624  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...      NaN   Đã bán 575
# 1625  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...      NaN    Đã bán 78
# 1626  https://tiki.vn/noi-dien-da-nang-phu-chong-din...      NaN  Đã bán 1.1k
# 1627  https://tiki.vn/noi-nau-cham-panasonic-nf-n31a...      NaN    Đã bán 74
# 1628  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...      NaN   Đã bán 659
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1624  dodungnhabep
# 1625  dodungnhabep
# 1626  dodungnhabep
# 1627  dodungnhabep
# 1628  dodungnhabep
#
# [1629 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        699000
# 1       2399000
# 2       1090000
# 3        216000
# 4       2940000
#          ...
# 1624    2150000
# 1625    1599000
# 1626     299000
# 1627    1299000
# 1628    1690000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        199.0
# 1         25.0
# 2       1100.0
# 3       1200.0
# 4        526.0
#          ...
# 1624     575.0
# 1625      78.0
# 1626    1100.0
# 1627      74.0
# 1628     659.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.391010e+08
# 1       5.997500e+07
# 2       1.199000e+09
# 3       2.592000e+08
# 4       1.546440e+09
#             ...
# 1624    1.236250e+09
# 1625    1.247220e+08
# 1626    3.289000e+08
# 1627    9.612600e+07
# 1628    1.113710e+09
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
# Out:
# Tổng doanh số đồ dùng nhà bếp:  284500544503.0

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
