# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\diengiadung\thietbigiadinh"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_tbgd_npage - Copy.ipynb',
#  'tk_dtsmartphone_all.ipynb',
#  'tk_mvb_Mamamy_t10.csv',
#  'tk_mvb_Mamamy_t11.csv',
#  'tk_mvb_Mamamy_t12.csv',
#  'tk_mvb_Mamamy_t13.csv',
#  'tk_mvb_Mamamy_t14.csv',
#  'tk_mvb_Mamamy_t15.csv',
#  'tk_mvb_Mamamy_t16.csv',
#  'tk_mvb_Mamamy_t17.csv',
#  'tk_mvb_Mamamy_t18.csv',
#  'tk_mvb_Mamamy_t19.csv',
#  'tk_mvb_Mamamy_t2.csv',
#  'tk_mvb_Mamamy_t20.csv',
#  'tk_mvb_Mamamy_t21.csv',
#  'tk_mvb_Mamamy_t22.csv',
#  'tk_mvb_Mamamy_t23.csv',
#  'tk_mvb_Mamamy_t24.csv',
#  'tk_mvb_Mamamy_t25.csv',
#  'tk_mvb_Mamamy_t26.csv',
#  'tk_mvb_Mamamy_t27.csv',
#  'tk_mvb_Mamamy_t28.csv',
#  'tk_mvb_Mamamy_t29.csv',
#  'tk_mvb_Mamamy_t3.csv',
#  'tk_mvb_Mamamy_t30.csv',
#  'tk_mvb_Mamamy_t31.csv',
#  'tk_mvb_Mamamy_t32.csv',
#  'tk_mvb_Mamamy_t33.csv',
#  'tk_mvb_Mamamy_t34.csv',
#  'tk_mvb_Mamamy_t35.csv',
#  'tk_mvb_Mamamy_t36.csv',
#  'tk_mvb_Mamamy_t37.csv',
#  'tk_mvb_Mamamy_t38.csv',
#  'tk_mvb_Mamamy_t39.csv',
#  'tk_mvb_Mamamy_t4.csv',
#  'tk_mvb_Mamamy_t40.csv',
#  'tk_mvb_Mamamy_t41.csv',
#  'tk_mvb_Mamamy_t42.csv',
#  'tk_mvb_Mamamy_t43.csv',
#  'tk_mvb_Mamamy_t44.csv',
#  'tk_mvb_Mamamy_t45.csv',
#  'tk_mvb_Mamamy_t46.csv',
#  'tk_mvb_Mamamy_t47.csv',
#  'tk_mvb_Mamamy_t48.csv',
#  'tk_mvb_Mamamy_t49.csv',
#  'tk_mvb_Mamamy_t5.csv',
#  'tk_mvb_Mamamy_t50.csv',
#  'tk_mvb_Mamamy_t6.csv',
#  'tk_mvb_Mamamy_t7.csv',
#  'tk_mvb_Mamamy_t8.csv',
#  'tk_mvb_Mamamy_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thietbigiadinh_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...    500.000₫
# 1   Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...    250.000₫
# 2     Bàn ủi hơi nước Philips GC482 - Hàng Chính Hãng  1.440.000₫
# 3   Máy Hút Bụi Không Dây Kachi Mk364 pin 3600mAh ...    569.050₫
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     69.000₫
# 37  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    603.000₫
# 38  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
# 39  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...    300.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/may-uon-toc-tu-dong-xoan-vivid...      1     -23%
# 1   https://tiki.vn/loi-loc-nuoc-toshiba-1686-1686...      2      -5%
# 2   https://tiki.vn/ban-ui-hoi-nuoc-philips-gc482-...      3      NaN
# 3   https://tiki.vn/may-hut-bui-khong-day-kachi-mk...      4      NaN
# 4   https://tiki.vn/may-lau-san-hut-bui-thong-minh...      5     -22%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...     36      NaN
# 36  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...     37      NaN
# 37  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...     38      NaN
# 38  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...     39      NaN
# 39  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...     40      NaN
#
#           sales  category
# 0    Đã bán 273  thietbij
# 1     Đã bán 25  thietbij
# 2     Đã bán 40  thietbij
# 3      Đã bán 1  thietbij
# 4           NaN  thietbij
# ..          ...       ...
# 35          NaN  thietbij
# 36    Đã bán 23  thietbij
# 37   Đã bán 393  thietbij
# 38  Đã bán 1.6k  thietbij
# 39   Đã bán 175  thietbij
#
# [1975 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['title'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...    500.000₫
# 1     Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...    250.000₫
# 2       Bàn ủi hơi nước Philips GC482 - Hàng Chính Hãng  1.440.000₫
# 3     Máy Hút Bụi Không Dây Kachi Mk364 pin 3600mAh ...    569.050₫
# 4     Máy hút bụi đệm giường, chăn nệm Deerma CM800 ...    749.000₫
# ...                                                 ...         ...
# 1624  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...    240.000₫
# 1625  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     69.000₫
# 1626  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    603.000₫
# 1627  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
# 1628  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...    300.000₫
#
#                                               link_item discount        sales  \
# 0     https://tiki.vn/may-uon-toc-tu-dong-xoan-vivid...     -23%   Đã bán 273
# 1     https://tiki.vn/loi-loc-nuoc-toshiba-1686-1686...      -5%    Đã bán 25
# 2     https://tiki.vn/ban-ui-hoi-nuoc-philips-gc482-...      NaN    Đã bán 40
# 3     https://tiki.vn/may-hut-bui-khong-day-kachi-mk...      NaN     Đã bán 1
# 4     https://tiki.vn/may-hut-bui-dem-giuong-chan-ne...      NaN  Đã bán 1.0k
# ...                                                 ...      ...          ...
# 1624  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     Đã bán 3
# 1625  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    Đã bán 23
# 1626  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   Đã bán 393
# 1627  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  Đã bán 1.6k
# 1628  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...      NaN   Đã bán 175
#
#       category
# 0     thietbij
# 1     thietbij
# 2     thietbij
# 3     thietbij
# 4     thietbij
# ...        ...
# 1624  thietbij
# 1625  thietbij
# 1626  thietbij
# 1627  thietbij
# 1628  thietbij
#
# [1629 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        500000
# 1        250000
# 2       1440000
# 3        569050
# 4        749000
#          ...
# 1624     240000
# 1625      69000
# 1626     603000
# 1627    1600000
# 1628     300000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        273.0
# 1         25.0
# 2         40.0
# 3          1.0
# 4       1000.0
#          ...
# 1624       3.0
# 1625      23.0
# 1626     393.0
# 1627    1600.0
# 1628     175.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.365000e+08
# 1       6.250000e+06
# 2       5.760000e+07
# 3       5.690500e+05
# 4       7.490000e+08
#             ...
# 1624    7.200000e+05
# 1625    1.587000e+06
# 1626    2.369790e+08
# 1627    2.560000e+09
# 1628    5.250000e+07
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thiết bị gia đình: ", total)
# Out:
# Tổng doanh số thiết bị gia đình:  142536282505.0

# %%
df_all.to_csv("tk_thietbigiadinh_all_ed.csv")
