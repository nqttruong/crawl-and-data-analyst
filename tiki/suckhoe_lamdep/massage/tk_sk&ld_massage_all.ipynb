# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\massage"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_massage_all.ipynb',
#  'tk_sk&ld_massage_npage - Copy (10).ipynb',
#  'tk_sk&ld_massage_t10.csv',
#  'tk_sk&ld_massage_t11.csv',
#  'tk_sk&ld_massage_t12.csv',
#  'tk_sk&ld_massage_t13.csv',
#  'tk_sk&ld_massage_t14.csv',
#  'tk_sk&ld_massage_t15.csv',
#  'tk_sk&ld_massage_t16.csv',
#  'tk_sk&ld_massage_t17.csv',
#  'tk_sk&ld_massage_t18.csv',
#  'tk_sk&ld_massage_t19.csv',
#  'tk_sk&ld_massage_t2.csv',
#  'tk_sk&ld_massage_t20.csv',
#  'tk_sk&ld_massage_t21.csv',
#  'tk_sk&ld_massage_t22.csv',
#  'tk_sk&ld_massage_t23.csv',
#  'tk_sk&ld_massage_t24.csv',
#  'tk_sk&ld_massage_t25.csv',
#  'tk_sk&ld_massage_t26.csv',
#  'tk_sk&ld_massage_t27.csv',
#  'tk_sk&ld_massage_t28.csv',
#  'tk_sk&ld_massage_t29.csv',
#  'tk_sk&ld_massage_t3.csv',
#  'tk_sk&ld_massage_t30.csv',
#  'tk_sk&ld_massage_t31.csv',
#  'tk_sk&ld_massage_t32.csv',
#  'tk_sk&ld_massage_t33.csv',
#  'tk_sk&ld_massage_t34.csv',
#  'tk_sk&ld_massage_t35.csv',
#  'tk_sk&ld_massage_t36.csv',
#  'tk_sk&ld_massage_t37.csv',
#  'tk_sk&ld_massage_t38.csv',
#  'tk_sk&ld_massage_t39.csv',
#  'tk_sk&ld_massage_t4.csv',
#  'tk_sk&ld_massage_t40.csv',
#  'tk_sk&ld_massage_t41.csv',
#  'tk_sk&ld_massage_t42.csv',
#  'tk_sk&ld_massage_t43.csv',
#  'tk_sk&ld_massage_t44.csv',
#  'tk_sk&ld_massage_t45.csv',
#  'tk_sk&ld_massage_t46.csv',
#  'tk_sk&ld_massage_t47.csv',
#  'tk_sk&ld_massage_t48.csv',
#  'tk_sk&ld_massage_t49.csv',
#  'tk_sk&ld_massage_t5.csv',
#  'tk_sk&ld_massage_t50.csv',
#  'tk_sk&ld_massage_t6.csv',
#  'tk_sk&ld_massage_t7.csv',
#  'tk_sk&ld_massage_t8.csv',
#  'tk_sk&ld_massage_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_massage_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy đo huyết áp bắp tay Omron năm các dòng 871...    799.000₫
# 1         Băng keo cá nhân nhiều hình combo 100 miếng     59.000₫
# 2                 Máy Đo Huyết Áp Cơ Microlife AG1-20    320.000₫
# 3    Túi chườm nóng lạnh Thiên Thanh cỡ nhỏ 27x22x7cm    105.000₫
# 4   Dụng cụ điện chẩn bằng sừng (MH816) CÂY CẠO GI...     59.000₫
# ..                                                ...         ...
# 35  [Công Nghệ Mới Cảnh Báo Đột Quỵ] Máy Đo Huyết ...  1.369.000₫
# 36                     Bàn lăn gỗ massage đa năng 100     85.000₫
# 37  Túi chườm nóng lạnh PUHA 350ml, túi chườm sưởi...    105.000₫
# 38  [HỘP - FAMAPRO VN95 KIDS] - Khẩu trang y tế tr...     10.900₫
# 39  Máy Massage làm ấm bụng, Đai chườm nóng bụng k...    751.060₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        799000
# 1         59000
# 2        320000
# 3        105000
# 4         59000
#          ...
# 1985    1369000
# 1986      85000
# 1987     105000
# 1988      10900
# 1989     751060
# Name: price, Length: 1990, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0          6.0
# 1        557.0
# 2          6.0
# 3        177.0
# 4         43.0
#          ...
# 1985       3.0
# 1986      66.0
# 1987     288.0
# 1988    1100.0
# 1989      12.0
# Name: sales, Length: 1990, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        4794000.0
# 1       32863000.0
# 2        1920000.0
# 3       18585000.0
# 4        2537000.0
#            ...
# 1985     4107000.0
# 1986     5610000.0
# 1987    30240000.0
# 1988    11990000.0
# 1989     9012720.0
# Name: revenue, Length: 1990, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số massage: ", total)
# Out:
# Tổng doanh số massage:  109342264718.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Máy đo huyết áp bắp tay Omron năm các dòng 871...   799000
# 1           Băng keo cá nhân nhiều hình combo 100 miếng    59000
# 2                   Máy Đo Huyết Áp Cơ Microlife AG1-20   320000
# 3      Túi chườm nóng lạnh Thiên Thanh cỡ nhỏ 27x22x7cm   105000
# 4     Dụng cụ điện chẩn bằng sừng (MH816) CÂY CẠO GI...    59000
# ...                                                 ...      ...
# 1985  [Công Nghệ Mới Cảnh Báo Đột Quỵ] Máy Đo Huyết ...  1369000
# 1986                     Bàn lăn gỗ massage đa năng 100    85000
# 1987  Túi chườm nóng lạnh PUHA 350ml, túi chườm sưởi...   105000
# 1988  [HỘP - FAMAPRO VN95 KIDS] - Khẩu trang y tế tr...    10900
# 1989  Máy Massage làm ấm bụng, Đai chườm nóng bụng k...   751060
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/may-do-huyet-ap-bap-tay-omron-...     -13%     6.0
# 1     https://tiki.vn/bang-keo-ca-nhan-nhieu-hinh-co...     -29%   557.0
# 2     https://tiki.vn/may-do-huyet-ap-co-microlife-a...     -34%     6.0
# 3     https://tiki.vn/tui-chuom-nong-lanh-thien-than...      -5%   177.0
# 4     https://tiki.vn/dung-cu-dien-chan-cay-cao-gio-...     -50%    43.0
# ...                                                 ...      ...     ...
# 1985  https://tiki.vn/cong-nghe-moi-canh-bao-dot-quy...      NaN     3.0
# 1986  https://tiki.vn/ban-lan-go-massage-da-nang-100...      NaN    66.0
# 1987  https://tiki.vn/tui-chuom-nong-lanh-puha-350ml...      NaN   288.0
# 1988  https://tiki.vn/hop-famapro-vn95-kids-khau-tra...      NaN  1100.0
# 1989  https://tiki.vn/tui-suoi-chuom-nuoc-nong-lanh-...      NaN    12.0
#
#          revenue
# 0      4794000.0
# 1     32863000.0
# 2      1920000.0
# 3     18585000.0
# 4      2537000.0
# ...          ...
# 1985   4107000.0
# 1986   5610000.0
# 1987  30240000.0
# 1988  11990000.0
# 1989   9012720.0
#
# [1990 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_massage_all_ed.csv")
