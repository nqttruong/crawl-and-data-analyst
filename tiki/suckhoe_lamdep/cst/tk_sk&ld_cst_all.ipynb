# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\cst"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_cst_all.ipynb',
#  'tk_sk&ld_cst_npage - Copy (7).ipynb',
#  'tk_sk&ld_cst_t10.csv',
#  'tk_sk&ld_cst_t11.csv',
#  'tk_sk&ld_cst_t12.csv',
#  'tk_sk&ld_cst_t13.csv',
#  'tk_sk&ld_cst_t14.csv',
#  'tk_sk&ld_cst_t15.csv',
#  'tk_sk&ld_cst_t16.csv',
#  'tk_sk&ld_cst_t17.csv',
#  'tk_sk&ld_cst_t18.csv',
#  'tk_sk&ld_cst_t19.csv',
#  'tk_sk&ld_cst_t2.csv',
#  'tk_sk&ld_cst_t20.csv',
#  'tk_sk&ld_cst_t21.csv',
#  'tk_sk&ld_cst_t22.csv',
#  'tk_sk&ld_cst_t23.csv',
#  'tk_sk&ld_cst_t24.csv',
#  'tk_sk&ld_cst_t25.csv',
#  'tk_sk&ld_cst_t26.csv',
#  'tk_sk&ld_cst_t27.csv',
#  'tk_sk&ld_cst_t28.csv',
#  'tk_sk&ld_cst_t29.csv',
#  'tk_sk&ld_cst_t3.csv',
#  'tk_sk&ld_cst_t30.csv',
#  'tk_sk&ld_cst_t31.csv',
#  'tk_sk&ld_cst_t32.csv',
#  'tk_sk&ld_cst_t33.csv',
#  'tk_sk&ld_cst_t34.csv',
#  'tk_sk&ld_cst_t35.csv',
#  'tk_sk&ld_cst_t36.csv',
#  'tk_sk&ld_cst_t37.csv',
#  'tk_sk&ld_cst_t38.csv',
#  'tk_sk&ld_cst_t39.csv',
#  'tk_sk&ld_cst_t4.csv',
#  'tk_sk&ld_cst_t40.csv',
#  'tk_sk&ld_cst_t41.csv',
#  'tk_sk&ld_cst_t42.csv',
#  'tk_sk&ld_cst_t43.csv',
#  'tk_sk&ld_cst_t44.csv',
#  'tk_sk&ld_cst_t45.csv',
#  'tk_sk&ld_cst_t46.csv',
#  'tk_sk&ld_cst_t47.csv',
#  'tk_sk&ld_cst_t48.csv',
#  'tk_sk&ld_cst_t49.csv',
#  'tk_sk&ld_cst_t5.csv',
#  'tk_sk&ld_cst_t50.csv',
#  'tk_sk&ld_cst_t6.csv',
#  'tk_sk&ld_cst_t7.csv',
#  'tk_sk&ld_cst_t8.csv',
#  'tk_sk&ld_cst_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_cst_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Dầu Gội Head&Shoulders Bạc Hà Mát Lạnh Chai 12...  284.000₫
# 1                  Dầu Gội Dove Phục Hồi Hư Tổn 880gr  181.000₫
# 2               Dầu Gội Pantene Ngăn Rụng Tóc - 650ML  143.000₫
# 3   Keo xịt tóc cực kỳ giữ nếp cấp độ 6 HARD HEAD ...  364.800₫
# 4           Dầu Gội Và Xả Bồ Kết Thorakao 400ml   67.000₫
# ..                                                ...       ...
# 35  Combo 5 hộp dầu gội thảo dược đen tóc TOSMEDY ...  119.000₫
 1000ml + Gội xả gói Karseell', '[+Tặng mũ trùm] TRỌN BỘ GỘI - XẢ - Ủ NASHI ARGAN 500ML', 'THUỐC UỐN TÓC PALLAMINA (UỐN LẠNH DẠNG GEL) 1000ML*2 MẪU MỚI', 'Combo 2 Dầu Gội Head & Shoulders Suôn Mềm Óng Mượt 625ml', '[Made in Japan] Mặt Nạ Tóc Cao Cấp Phục Hồi Hư Tổn TSUBAKI (180g)', 'Dầu Gội Vedette Ô-liu 500g (TPM371)', 'Dầu gội Sunsilk Mềm Mượt Diệu Kỳ 1.4kg giúp tóc ngát hương mềm mượt gấp 5 lần với dầu Argan, Protein Tơ Tằm và Vitamin C', 'Dầu g ...

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Dầu Gội Head&Shoulders Bạc Hà Mát Lạnh Chai 12...  284.000₫
# 1                    Dầu Gội Dove Phục Hồi Hư Tổn 880gr  181.000₫
# 2                 Dầu Gội Pantene Ngăn Rụng Tóc - 650ML  143.000₫
# 3     Keo xịt tóc cực kỳ giữ nếp cấp độ 6 HARD HEAD ...  364.800₫
# 4             Dầu Gội Và Xả Bồ Kết Thorakao 400ml   67.000₫
# ...                                                 ...       ...
# 1970  Combo 5 hộp dầu gội thảo dược đen tóc TOSMEDY ...  119.000₫
# 1971  Gói Dầu Gội Phủ Bạc, Nhuộm Tóc Thảo Dược Manka...   35.000₫
# 1972  Nhuộm phủ bạc nhanh 1 phút Jichung 1 Minute Ha...  149.000₫
# 1973  Thuốc nhuộm phủ bạc YOUNG màu tự nhiên và thời...   42.000₫
# 1974              Dầu Gội Rejoice Siêu Mượt Chai 1800ML  358.000₫
#
#                                               link_item discount        sales
# 0     https://tiki.vn/dau-goi-head-shoulders-bac-ha-...     -13%    Đã bán 30
# 1     https://tiki.vn/dau-goi-dove-phuc-hoi-hu-ton-8...     -16%  Đã bán 1.9k
# 2     https://tiki.vn/dau-goi-pantene-ngan-rung-toc-...     -13%     Đã bán 5
# 3     https://tiki.vn/keo-xit-toc-cuc-ky-giu-nep-cap...      -5%    Đã bán 39
# 4     https://tiki.vn/da-u-go-i-va-xa-bo-ke-t-thorak...     -19%   Đã bán 107
# ...                                                 ...      ...          ...
# 1970  https://tiki.vn/combo-5-hop-dau-goi-thao-duoc-...      NaN   Đã bán 234
# 1971  https://tiki.vn/goi-dau-goi-phu-bac-thao-duoc-...      NaN    Đã bán 75
# 1972  https://tiki.vn/nhuom-phu-bac-nhanh-1-phut-jic...      NaN    Đã bán 51
# 1973  https://tiki.vn/phu-bac-young-p166119146.html?...      NaN     Đã bán 7
# 1974  https://tiki.vn/dau-goi-rejoice-sieu-muot-chai...      NaN          NaN
#
# [1975 rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       284000
# 1       181000
# 2       143000
# 3       364800
# 4        67000
#          ...
# 1970    119000
# 1971     35000
# 1972    149000
# 1973     42000
# 1974    358000
# Name: price, Length: 1975, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         30.0
# 1       1900.0
# 2          5.0
# 3         39.0
# 4        107.0
#          ...
# 1970     234.0
# 1971      75.0
# 1972      51.0
# 1973       7.0
# 1974       NaN
# Name: sales, Length: 1975, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         8520000.0
# 1       343900000.0
# 2          715000.0
# 3        14227200.0
# 4         7169000.0
#            ...
# 1970     27846000.0
# 1971      2625000.0
# 1972      7599000.0
# 1973       294000.0
# 1974            NaN
# Name: revenue, Length: 1975, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chăm sóc tóc: ", total)
# Out:
# Tổng doanh số chăm sóc tóc:  57520052958.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Dầu Gội Head&Shoulders Bạc Hà Mát Lạnh Chai 12...  284000
# 1                    Dầu Gội Dove Phục Hồi Hư Tổn 880gr  181000
# 2                 Dầu Gội Pantene Ngăn Rụng Tóc - 650ML  143000
# 3     Keo xịt tóc cực kỳ giữ nếp cấp độ 6 HARD HEAD ...  364800
# 4             Dầu Gội Và Xả Bồ Kết Thorakao 400ml   67000
# ...                                                 ...     ...
# 1970  Combo 5 hộp dầu gội thảo dược đen tóc TOSMEDY ...  119000
# 1971  Gói Dầu Gội Phủ Bạc, Nhuộm Tóc Thảo Dược Manka...   35000
# 1972  Nhuộm phủ bạc nhanh 1 phút Jichung 1 Minute Ha...  149000
# 1973  Thuốc nhuộm phủ bạc YOUNG màu tự nhiên và thời...   42000
# 1974              Dầu Gội Rejoice Siêu Mượt Chai 1800ML  358000
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/dau-goi-head-shoulders-bac-ha-...     -13%    30.0
# 1     https://tiki.vn/dau-goi-dove-phuc-hoi-hu-ton-8...     -16%  1900.0
# 2     https://tiki.vn/dau-goi-pantene-ngan-rung-toc-...     -13%     5.0
# 3     https://tiki.vn/keo-xit-toc-cuc-ky-giu-nep-cap...      -5%    39.0
# 4     https://tiki.vn/da-u-go-i-va-xa-bo-ke-t-thorak...     -19%   107.0
# ...                                                 ...      ...     ...
# 1970  https://tiki.vn/combo-5-hop-dau-goi-thao-duoc-...      NaN   234.0
# 1971  https://tiki.vn/goi-dau-goi-phu-bac-thao-duoc-...      NaN    75.0
# 1972  https://tiki.vn/nhuom-phu-bac-nhanh-1-phut-jic...      NaN    51.0
# 1973  https://tiki.vn/phu-bac-young-p166119146.html?...      NaN     7.0
# 1974  https://tiki.vn/dau-goi-rejoice-sieu-muot-chai...      NaN     NaN
#
#           revenue
# 0       8520000.0
# 1     343900000.0
# 2        715000.0
# 3      14227200.0
# 4       7169000.0
# ...           ...
# 1970   27846000.0
# 1971    2625000.0
# 1972    7599000.0
# 1973     294000.0
# 1974          NaN
#
# [1975 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_cst_all_ed.csv")
