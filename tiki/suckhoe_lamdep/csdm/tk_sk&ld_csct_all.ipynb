# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\csdm"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_csct_all.ipynb',
#  'tk_sk&ld_csdm_npage - Copy (2).ipynb',
#  'tk_sk&ld_csdm_t10.csv',
#  'tk_sk&ld_csdm_t11.csv',
#  'tk_sk&ld_csdm_t12.csv',
#  'tk_sk&ld_csdm_t13.csv',
#  'tk_sk&ld_csdm_t14.csv',
#  'tk_sk&ld_csdm_t15.csv',
#  'tk_sk&ld_csdm_t16.csv',
#  'tk_sk&ld_csdm_t17.csv',
#  'tk_sk&ld_csdm_t18.csv',
#  'tk_sk&ld_csdm_t19.csv',
#  'tk_sk&ld_csdm_t2.csv',
#  'tk_sk&ld_csdm_t20.csv',
#  'tk_sk&ld_csdm_t21.csv',
#  'tk_sk&ld_csdm_t22.csv',
#  'tk_sk&ld_csdm_t23.csv',
#  'tk_sk&ld_csdm_t24.csv',
#  'tk_sk&ld_csdm_t25.csv',
#  'tk_sk&ld_csdm_t26.csv',
#  'tk_sk&ld_csdm_t27.csv',
#  'tk_sk&ld_csdm_t28.csv',
#  'tk_sk&ld_csdm_t29.csv',
#  'tk_sk&ld_csdm_t3.csv',
#  'tk_sk&ld_csdm_t30.csv',
#  'tk_sk&ld_csdm_t31.csv',
#  'tk_sk&ld_csdm_t32.csv',
#  'tk_sk&ld_csdm_t33.csv',
#  'tk_sk&ld_csdm_t34.csv',
#  'tk_sk&ld_csdm_t35.csv',
#  'tk_sk&ld_csdm_t36.csv',
#  'tk_sk&ld_csdm_t37.csv',
#  'tk_sk&ld_csdm_t38.csv',
#  'tk_sk&ld_csdm_t39.csv',
#  'tk_sk&ld_csdm_t4.csv',
#  'tk_sk&ld_csdm_t40.csv',
#  'tk_sk&ld_csdm_t41.csv',
#  'tk_sk&ld_csdm_t42.csv',
#  'tk_sk&ld_csdm_t43.csv',
#  'tk_sk&ld_csdm_t44.csv',
#  'tk_sk&ld_csdm_t45.csv',
#  'tk_sk&ld_csdm_t46.csv',
#  'tk_sk&ld_csdm_t47.csv',
#  'tk_sk&ld_csdm_t48.csv',
#  'tk_sk&ld_csdm_t49.csv',
#  'tk_sk&ld_csdm_t5.csv',
#  'tk_sk&ld_csdm_t50.csv',
#  'tk_sk&ld_csdm_t6.csv',
#  'tk_sk&ld_csdm_t7.csv',
#  'tk_sk&ld_csdm_t8.csv',
#  'tk_sk&ld_csdm_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_csdm_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0            COMBO CƠ BẢN CHO DA MỤN DECUMAR ADVANCED  145.000₫
# 1   Nước hoa hồng dành cho da khô da nhạy cảm Huxl...  348.000₫
# 2              Sữa Rửa Mặt Collagen 3W Clinic (100ml)   25.000₫
# 3   Serum Mờ Thâm Trắng Da Kiềm Dầu Se Khít Lỗ Châ...  175.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  
https://tiki.vn/mat-na-sinh-hoc-xoa-tham-va-ne...      NaN   Đã bán 184
#
# [1629 rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       145000
# 1       348000
# 2        25000
# 3       175000
# 4        85000
#          ...
# 1624     31000
# 1625    108000
# 1626    400000
# 1627    175000
# 1628    400000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        621.0
# 1        127.0
# 2         70.0
# 3        138.0
# 4       1200.0
#          ...
# 1624     217.0
# 1625     212.0
# 1626     326.0
# 1627      42.0
# 1628     184.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        90045000.0
# 1        44196000.0
# 2         1750000.0
# 3        24150000.0
# 4       102000000.0
#            ...
# 1624      6727000.0
# 1625     22896000.0
# 1626    130400000.0
# 1627      7350000.0
# 1628     73600000.0
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chăm sóc da mặt: ", total)
# Out:
# Tổng doanh số chăm sóc da mặt:  95366368015.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0              COMBO CƠ BẢN CHO DA MỤN DECUMAR ADVANCED  145000
# 1     Nước hoa hồng dành cho da khô da nhạy cảm Huxl...  348000
# 2                Sữa Rửa Mặt Collagen 3W Clinic (100ml)   25000
# 3     Serum Mờ Thâm Trắng Da Kiềm Dầu Se Khít Lỗ Châ...  175000
# 4     Mặt nạ giấy dưỡng trắng da nhạy cảm mụn thải đ...   85000
# ...                                                 ...     ...
# 1624                Kem Nghệ Dưỡng Da Mụn Thorakao 7g   31000
# 1625  Nước tẩy trang sạch sâu dưỡng trắng Hada Labo ...  108000
# 1626  [CHÍNH HÃNG] Mặt Nạ Sinh Học Xóa Thâm Và Nếp N...  400000
# 1627  Kem dưỡng ẩm chuyên sâu cho da rất khô và viêm...  175000
# 1628  [CHÍNH HÃNG] Mặt Nạ Sinh Học Xóa Thâm Và Nếp N...  400000
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/combo-co-ban-cho-da-mun-decuma...      -6%   621.0
# 1     https://tiki.vn/nuoc-hoa-hong-danh-cho-da-kho-...     -20%   127.0
# 2     https://tiki.vn/sua-rua-mat-collagen-3w-clinic...     -37%    70.0
# 3     https://tiki.vn/serum-mo-tham-trang-da-kiem-da...     -39%   138.0
# 4     https://tiki.vn/mat-na-giay-duong-trang-da-nha...      -5%  1200.0
# ...                                                 ...      ...     ...
# 1624  https://tiki.vn/kem-nghe-duo-ng-da-mu-n-thorak...      NaN   217.0
# 1625  https://tiki.vn/nuoc-tay-trang-sach-sau-duong-...      NaN   212.0
# 1626  https://tiki.vn/mat-na-sinh-hoc-xoa-tham-va-ne...      NaN   326.0
# 1627  https://tiki.vn/kem-duong-am-chuyen-sau-cho-da...      NaN    42.0
# 1628  https://tiki.vn/mat-na-sinh-hoc-xoa-tham-va-ne...      NaN   184.0
#
#           revenue
# 0      90045000.0
# 1      44196000.0
# 2       1750000.0
# 3      24150000.0
# 4     102000000.0
# ...           ...
# 1624    6727000.0
# 1625   22896000.0
# 1626  130400000.0
# 1627    7350000.0
# 1628   73600000.0
#
# [1629 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_csdm_all_ed.csv")
