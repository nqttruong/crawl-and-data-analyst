# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\httd"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_httd_all.ipynb',
#  'tk_sk&ld_httd_npage - Copy (12).ipynb',
#  'tk_sk&ld_httd_t10.csv',
#  'tk_sk&ld_httd_t11.csv',
#  'tk_sk&ld_httd_t12.csv',
#  'tk_sk&ld_httd_t13.csv',
#  'tk_sk&ld_httd_t14.csv',
#  'tk_sk&ld_httd_t15.csv',
#  'tk_sk&ld_httd_t16.csv',
#  'tk_sk&ld_httd_t17.csv',
#  'tk_sk&ld_httd_t18.csv',
#  'tk_sk&ld_httd_t19.csv',
#  'tk_sk&ld_httd_t2.csv',
#  'tk_sk&ld_httd_t20.csv',
#  'tk_sk&ld_httd_t21.csv',
#  'tk_sk&ld_httd_t22.csv',
#  'tk_sk&ld_httd_t23.csv',
#  'tk_sk&ld_httd_t24.csv',
#  'tk_sk&ld_httd_t25.csv',
#  'tk_sk&ld_httd_t26.csv',
#  'tk_sk&ld_httd_t27.csv',
#  'tk_sk&ld_httd_t28.csv',
#  'tk_sk&ld_httd_t29.csv',
#  'tk_sk&ld_httd_t3.csv',
#  'tk_sk&ld_httd_t30.csv',
#  'tk_sk&ld_httd_t31.csv',
#  'tk_sk&ld_httd_t32.csv',
#  'tk_sk&ld_httd_t33.csv',
#  'tk_sk&ld_httd_t34.csv',
#  'tk_sk&ld_httd_t35.csv',
#  'tk_sk&ld_httd_t36.csv',
#  'tk_sk&ld_httd_t37.csv',
#  'tk_sk&ld_httd_t4.csv',
#  'tk_sk&ld_httd_t5.csv',
#  'tk_sk&ld_httd_t6.csv',
#  'tk_sk&ld_httd_t7.csv',
#  'tk_sk&ld_httd_t8.csv',
#  'tk_sk&ld_httd_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_httd_all.csv", index="False")

# %%
df_all = pd.read_csv("tk_sk&ld_httd_all.csv")
df_all
# Out:
#       Unnamed: 0                                              title     price  \
# 0              0  Bao cao su Ritex Lust, gân gai đan xen, hộp 3 ...   90.000₫
# 1              1  Bao cao su Sagami Are Are - thương hiệu Nhật B...   66.500₫
# 2              2      Bao cao su Tâm Thiện Chí Guardian Hộp 144 cái  146.000₫
# 3              3  Gel Bôi Trơn Hậu Môn Gốc Nước Cao Cấp Của Đức ...   40.000₫
# 4              4                                                NaN       NaN
# ...          ...                                                ...       ...
# 1443          35                                                NaN       NaN
# 1444          36   Bao cao su Pharmacity Unlimited Love (Hộp 3 cái)   18.800₫
# 1445          37                                Bao cao su Powermen   54.000₫
# 1446          38       Bao cao su Sagami Xtreme Green (10 Cái/ Hộp)   65.778₫
# 1447          39  Bao cao su gân gai, kéo dài thời gian Powermen...   25.000₫
#
#                                               link_item  index discount  \
# 0     https://tiki.vn/bao-cao-su-ritex-lust-gan-gai-...      1      -5%
# 1     https://tiki.vn/bao-cao-su-sagami-are-are-thuo...      2     -38%
# 2     https://tiki.vn/bao-cao-su-tam-thien-chi-guard...      3     -52%
# 3     https://tiki.vn/gel-boi-tron-hau-mon-goc-nuoc-...      4      -7%
# 4     https://tiki.vn/gel-boi-tron-goc-silicon-giam-...      5     -19%
# ...                                                 ...    ...      ...
# 1443  https://tiki.vn/bao-cao-su-okamoto-0-01-large-...     36      NaN
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       106.0
# 1         1.0
# 2         3.0
# 3         NaN
# 4         NaN
#         ...
# 1151     37.0
# 1152      8.0
# 1153     12.0
# 1154     89.0
# 1155     34.0
# Name: sales, Length: 1156, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        9540000.0
# 1          66500.0
# 2         438000.0
# 3              NaN
# 4              NaN
#            ...
# 1151    12654000.0
# 1152      150400.0
# 1153      648000.0
# 1154     5854242.0
# 1155      850000.0
# Name: revenue, Length: 1156, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số httd: ", total)
# Out:
# Tổng doanh số httd:  6130774928.0

# %%
df_all
# Out:
#       Unnamed: 0                                              title   price  \
# 0              0  Bao cao su Ritex Lust, gân gai đan xen, hộp 3 ...   90000
# 1              1  Bao cao su Sagami Are Are - thương hiệu Nhật B...   66500
# 2              2      Bao cao su Tâm Thiện Chí Guardian Hộp 144 cái  146000
# 3              3  Gel Bôi Trơn Hậu Môn Gốc Nước Cao Cấp Của Đức ...   40000
# 4              5  Bộ 2 Hộp Bao Cao Su Siêu Mỏng Cao Cấp Sagami X...  121000
# ...          ...                                                ...     ...
# 1151          34  Gel bôi trơn hậu môn tinh chất lô hội - Shell ...  342000
# 1152          36   Bao cao su Pharmacity Unlimited Love (Hộp 3 cái)   18800
# 1153          37                                Bao cao su Powermen   54000
# 1154          38       Bao cao su Sagami Xtreme Green (10 Cái/ Hộp)   65778
# 1155          39  Bao cao su gân gai, kéo dài thời gian Powermen...   25000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/bao-cao-su-ritex-lust-gan-gai-...      -5%  106.0
# 1     https://tiki.vn/bao-cao-su-sagami-are-are-thuo...     -38%    1.0
# 2     https://tiki.vn/bao-cao-su-tam-thien-chi-guard...     -52%    3.0
# 3     https://tiki.vn/gel-boi-tron-hau-mon-goc-nuoc-...      -7%    NaN
# 4     https://tiki.vn/bo-2-hop-bao-cao-su-sieu-mong-...     -18%    NaN
# ...                                                 ...      ...    ...
# 1151  https://tiki.vn/gel-boi-tron-hau-mon-tinh-chat...      NaN   37.0
# 1152  https://tiki.vn/bao-cao-su-pharmacity-unlimite...      NaN    8.0
# 1153  https://tiki.vn/bao-cao-su-powermen-p13553261....      NaN   12.0
# 1154  https://tiki.vn/bao-cao-su-sagami-xtreme-green...      NaN   89.0
# 1155  https://tiki.vn/bao-cao-su-gan-gai-keo-dai-tho...      NaN   34.0
#
#          revenue
# 0      9540000.0
# 1        66500.0
# 2       438000.0
# 3            NaN
# 4            NaN
# ...          ...
# 1151  12654000.0
# 1152    150400.0
# 1153    648000.0
# 1154   5854242.0
# 1155    850000.0
#
# [1156 rows x 7 columns]

# %%
df_all.to_csv("tk_sk&ld_httd_all_ed.csv")
