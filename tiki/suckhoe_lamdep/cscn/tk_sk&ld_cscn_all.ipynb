# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\cscn"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_cscn_all.ipynb',
#  'tk_sk&ld_cscn_npage - Copy (4).ipynb',
#  'tk_sk&ld_cscn_t10.csv',
#  'tk_sk&ld_cscn_t11.csv',
#  'tk_sk&ld_cscn_t12.csv',
#  'tk_sk&ld_cscn_t13.csv',
#  'tk_sk&ld_cscn_t14.csv',
#  'tk_sk&ld_cscn_t15.csv',
#  'tk_sk&ld_cscn_t16.csv',
#  'tk_sk&ld_cscn_t17.csv',
#  'tk_sk&ld_cscn_t18.csv',
#  'tk_sk&ld_cscn_t19.csv',
#  'tk_sk&ld_cscn_t2.csv',
#  'tk_sk&ld_cscn_t20.csv',
#  'tk_sk&ld_cscn_t21.csv',
#  'tk_sk&ld_cscn_t22.csv',
#  'tk_sk&ld_cscn_t23.csv',
#  'tk_sk&ld_cscn_t24.csv',
#  'tk_sk&ld_cscn_t25.csv',
#  'tk_sk&ld_cscn_t26.csv',
#  'tk_sk&ld_cscn_t27.csv',
#  'tk_sk&ld_cscn_t28.csv',
#  'tk_sk&ld_cscn_t29.csv',
#  'tk_sk&ld_cscn_t3.csv',
#  'tk_sk&ld_cscn_t30.csv',
#  'tk_sk&ld_cscn_t31.csv',
#  'tk_sk&ld_cscn_t32.csv',
#  'tk_sk&ld_cscn_t33.csv',
#  'tk_sk&ld_cscn_t34.csv',
#  'tk_sk&ld_cscn_t35.csv',
#  'tk_sk&ld_cscn_t36.csv',
#  'tk_sk&ld_cscn_t37.csv',
#  'tk_sk&ld_cscn_t38.csv',
#  'tk_sk&ld_cscn_t39.csv',
#  'tk_sk&ld_cscn_t4.csv',
#  'tk_sk&ld_cscn_t40.csv',
#  'tk_sk&ld_cscn_t41.csv',
#  'tk_sk&ld_cscn_t42.csv',
#  'tk_sk&ld_cscn_t43.csv',
#  'tk_sk&ld_cscn_t44.csv',
#  'tk_sk&ld_cscn_t45.csv',
#  'tk_sk&ld_cscn_t46.csv',
#  'tk_sk&ld_cscn_t47.csv',
#  'tk_sk&ld_cscn_t48.csv',
#  'tk_sk&ld_cscn_t49.csv',
#  'tk_sk&ld_cscn_t5.csv',
#  'tk_sk&ld_cscn_t50.csv',
#  'tk_sk&ld_cscn_t6.csv',
#  'tk_sk&ld_cscn_t7.csv',
#  'tk_sk&ld_cscn_t8.csv',
#  'tk_sk&ld_cscn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_cscn_all.csv", index="False")

# %%
df_all[]
# Out:
#                                                 title     price  \
# 0   Bình Rửa Mũi Xoang PlasmaKare Nasal Clean - Là...  235.000₫
# 1   Băng vệ sinh Kotex Hàng ngày Kháng khuẩn Siêu ...   27.000₫
# 2     Combo 3 Bông Tăm Kháng Khuẩn Jomi (160 Que/Hộp)   79.000₫
# 3   Dung dịch vệ sinh phụ nữ INTIMA Hoa lan chuông...  160.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Combo 3 Băng Vệ Sinh Laurier Fresh & Free Dày ...  126.000₫
# 37        Combo 6 bvs Kotex đêm dạng quần M/L 2 miếng  175.000₫
# 38  Combo 6 Băng vệ sinh ban đêm Doctor Care tinh ...   97.000₫
# 39  Bộ 2 bàn chải cho răng ê buốt Sensodyne Sensit...   43.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn
columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       235000
# 1        27000
# 2        79000
# 3       160000
# 4        39000
#          ...
# 1624    200000
# 1625    126000
# 1626    175000
# 1627     97000
# 1628     43000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        13.0
# 1       134.0
# 2        34.0
# 3        87.0
# 4       285.0
#         ...
# 1624     50.0
# 1625    420.0
# 1626    181.0
# 1627    529.0
# 1628    172.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        3055000.0
# 1        3618000.0
# 2        2686000.0
# 3       13920000.0
# 4       11115000.0
#            ...
# 1624    10000000.0
# 1625    52920000.0
# 1626    31675000.0
# 1627    51313000.0
# 1628     7396000.0
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chăm sóc cá nhân: ", total)
# Out:
# Tổng doanh số chăm sóc cá nhân:  44258202188.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bình Rửa Mũi Xoang PlasmaKare Nasal Clean - Là...  235000
# 1     Băng vệ sinh Kotex Hàng ngày Kháng khuẩn Siêu ...   27000
# 2       Combo 3 Bông Tăm Kháng Khuẩn Jomi (160 Que/Hộp)   79000
# 3     Dung dịch vệ sinh phụ nữ INTIMA Hoa lan chuông...  160000
# 4          Bọt Cạo Râu GILLETTE London Bridge Chai 300g   39000
# ...                                                 ...     ...
# 1624  Combo 5 gói Tăm chỉ kẽ răng Okamura 90 cây/gói...  200000
# 1625  Combo 3 Băng Vệ Sinh Laurier Fresh & Free Dày ...  126000
# 1626        Combo 6 bvs Kotex đêm dạng quần M/L 2 miếng  175000
# 1627  Combo 6 Băng vệ sinh ban đêm Doctor Care tinh ...   97000
# 1628  Bộ 2 bàn chải cho răng ê buốt Sensodyne Sensit...   43000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/bo-rua-mui-xoang-plasmakare-na...     -22%   13.0
# 1     https://tiki.vn/bang-ve-sinh-kotex-hang-ngay-k...     -20%  134.0
# 2     https://tiki.vn/combo-3-bong-tam-khang-khuan-j...      NaN   34.0
# 3     https://tiki.vn/dung-dich-ve-sinh-phu-nu-intim...     -40%   87.0
# 4     https://tiki.vn/bot-cao-rau-gillette-london-br...     -53%  285.0
# ...                                                 ...      ...    ...
# 1624  https://tiki.vn/combo-5-goi-tam-chi-ke-rang-ok...      NaN   50.0
# 1625  https://tiki.vn/combo-3-bang-ve-sinh-laurier-f...      NaN  420.0
# 1626  https://tiki.vn/combo-6-bvs-kotex-dem-dang-qua...      NaN  181.0
# 1627  https://tiki.vn/combo-6-bang-ve-sinh-ban-dem-d...      NaN  529.0
# 1628  https://tiki.vn/bo-2-ban-chai-cho-rang-e-buot-...      NaN  172.0
#
#          revenue
# 0      3055000.0
# 1      3618000.0
# 2      2686000.0
# 3     13920000.0
# 4     11115000.0
# ...          ...
# 1624  10000000.0
# 1625  52920000.0
# 1626  31675000.0
# 1627  51313000.0
# 1628   7396000.0
#
# [1629 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_cscn_all_ed.csv")
