# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\dcld"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_cst_all.ipynb',
#  'tk_sk&ld_dcld_npage - Copy (9).ipynb',
#  'tk_sk&ld_dcld_t10.csv',
#  'tk_sk&ld_dcld_t11.csv',
#  'tk_sk&ld_dcld_t12.csv',
#  'tk_sk&ld_dcld_t13.csv',
#  'tk_sk&ld_dcld_t14.csv',
#  'tk_sk&ld_dcld_t15.csv',
#  'tk_sk&ld_dcld_t16.csv',
#  'tk_sk&ld_dcld_t17.csv',
#  'tk_sk&ld_dcld_t18.csv',
#  'tk_sk&ld_dcld_t19.csv',
#  'tk_sk&ld_dcld_t2.csv',
#  'tk_sk&ld_dcld_t20.csv',
#  'tk_sk&ld_dcld_t21.csv',
#  'tk_sk&ld_dcld_t22.csv',
#  'tk_sk&ld_dcld_t23.csv',
#  'tk_sk&ld_dcld_t24.csv',
#  'tk_sk&ld_dcld_t25.csv',
#  'tk_sk&ld_dcld_t26.csv',
#  'tk_sk&ld_dcld_t27.csv',
#  'tk_sk&ld_dcld_t28.csv',
#  'tk_sk&ld_dcld_t29.csv',
#  'tk_sk&ld_dcld_t3.csv',
#  'tk_sk&ld_dcld_t30.csv',
#  'tk_sk&ld_dcld_t31.csv',
#  'tk_sk&ld_dcld_t32.csv',
#  'tk_sk&ld_dcld_t33.csv',
#  'tk_sk&ld_dcld_t34.csv',
#  'tk_sk&ld_dcld_t35.csv',
#  'tk_sk&ld_dcld_t36.csv',
#  'tk_sk&ld_dcld_t37.csv',
#  'tk_sk&ld_dcld_t38.csv',
#  'tk_sk&ld_dcld_t39.csv',
#  'tk_sk&ld_dcld_t4.csv',
#  'tk_sk&ld_dcld_t40.csv',
#  'tk_sk&ld_dcld_t41.csv',
#  'tk_sk&ld_dcld_t42.csv',
#  'tk_sk&ld_dcld_t43.csv',
#  'tk_sk&ld_dcld_t44.csv',
#  'tk_sk&ld_dcld_t45.csv',
#  'tk_sk&ld_dcld_t46.csv',
#  'tk_sk&ld_dcld_t47.csv',
#  'tk_sk&ld_dcld_t48.csv',
#  'tk_sk&ld_dcld_t49.csv',
#  'tk_sk&ld_dcld_t5.csv',
#  'tk_sk&ld_dcld_t50.csv',
#  'tk_sk&ld_dcld_t6.csv',
#  'tk_sk&ld_dcld_t7.csv',
#  'tk_sk&ld_dcld_t8.csv',
#  'tk_sk&ld_dcld_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_dcld_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ lưỡi máy cạo râu thay thế cho dòng máy cạo ...   79.000₫
# 1                                  Nước rửa siêu mạnh    8.000₫
# 2   10 Que gỗ gạt sáp wax lông size to gấp 2 lần q...    2.500₫
# 3   Máy Cạo Lông Vùng Kín KM Giúp Tẩy Lông Hiệu Qu...  113.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        79000
# 1         8000
# 2         2500
# 3       113000
# 4       109000
#          ...
# 1624     56000
# 1625    630000
# 1626    199000
# 1627     53000
# 1628    115000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0          1.0
# 1          6.0
# 2         22.0
# 3         10.0
# 4       1100.0
#          ...
# 1624      95.0
# 1625      11.0
# 1626      55.0
# 1627      17.0
# 1628      28.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0           79000.0
# 1           48000.0
# 2           55000.0
# 3         1130000.0
# 4       119900000.0
#            ...
# 1624      5320000.0
# 1625      6930000.0
# 1626     10945000.0
# 1627       901000.0
# 1628      3220000.0
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dụng cụ làm đẹp: ", total)
# Out:
# Tổng doanh số dụng cụ làm đẹp:  15954034023.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bộ lưỡi máy cạo râu thay thế cho dòng máy cạo ...   79000
# 1                                    Nước rửa siêu mạnh    8000
# 2     10 Que gỗ gạt sáp wax lông size to gấp 2 lần q...    2500
# 3     Máy Cạo Lông Vùng Kín KM Giúp Tẩy Lông Hiệu Qu...  113000
# 4     Cold wax an lành - Wax lông - Tẩy lông - Tặng ...  109000
# ...                                                 ...     ...
# 1624                     Dao Cạo Râu Chuyên Nghiệp NQ88   56000
# 1625  Máy rửa mặt rung massage cao cấp MASEKI NHẬT B...  630000
# 1626  Guasha Thạch Anh Hồng (rose quartz) - Sản phẩm...  199000
# 1627                               Sơn Base Gel Vinimay   53000
# 1628  Combo Chén Silicon Nấu Sáp + Sáp Wax Lông Hann...  115000
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/bo-luoi-may-cao-rau-thay-the-c...      -6%     1.0
# 1     https://tiki.vn/nuoc-rua-sieu-manh-p248616060....     -48%     6.0
# 2     https://tiki.vn/10-que-go-gat-sap-wax-long-siz...     -15%    22.0
# 3     https://tiki.vn/may-cao-long-vung-kin-may-cao-...      -5%    10.0
# 4     https://tiki.vn/cold-wax-an-lanh-wax-long-tay-...      -8%  1100.0
# ...                                                 ...      ...     ...
# 1624  https://tiki.vn/dao-cao-rau-chuyen-nghiep-nq88...      NaN    95.0
# 1625  https://tiki.vn/may-rua-mat-rung-massage-cao-c...      NaN    11.0
# 1626  https://tiki.vn/guasha-thach-anh-hong-rose-qua...      NaN    55.0
# 1627  https://tiki.vn/son-base-gel-vinimay-p14322648...      NaN    17.0
# 1628  https://tiki.vn/combo-chen-silicon-nau-sap-sap...      NaN    28.0
#
#           revenue
# 0         79000.0
# 1         48000.0
# 2         55000.0
# 3       1130000.0
# 4     119900000.0
# ...           ...
# 1624    5320000.0
# 1625    6930000.0
# 1626   10945000.0
# 1627     901000.0
# 1628    3220000.0
#
# [1629 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_dcld_all_ed.csv")
