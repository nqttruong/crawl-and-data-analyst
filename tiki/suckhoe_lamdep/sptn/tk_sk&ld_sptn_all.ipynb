# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\sptn"
os.listdir(path)
# Out:
# ['tk_sk&ld_nuochoa_all.ipynb',
#  'tk_sk&ld_sptn_npage - Copy (6).ipynb',
#  'tk_sk&ld_sptn_t10.csv',
#  'tk_sk&ld_sptn_t11.csv',
#  'tk_sk&ld_sptn_t12.csv',
#  'tk_sk&ld_sptn_t13.csv',
#  'tk_sk&ld_sptn_t14.csv',
#  'tk_sk&ld_sptn_t15.csv',
#  'tk_sk&ld_sptn_t16.csv',
#  'tk_sk&ld_sptn_t17.csv',
#  'tk_sk&ld_sptn_t18.csv',
#  'tk_sk&ld_sptn_t19.csv',
#  'tk_sk&ld_sptn_t2.csv',
#  'tk_sk&ld_sptn_t20.csv',
#  'tk_sk&ld_sptn_t21.csv',
#  'tk_sk&ld_sptn_t22.csv',
#  'tk_sk&ld_sptn_t23.csv',
#  'tk_sk&ld_sptn_t24.csv',
#  'tk_sk&ld_sptn_t25.csv',
#  'tk_sk&ld_sptn_t26.csv',
#  'tk_sk&ld_sptn_t27.csv',
#  'tk_sk&ld_sptn_t28.csv',
#  'tk_sk&ld_sptn_t29.csv',
#  'tk_sk&ld_sptn_t3.csv',
#  'tk_sk&ld_sptn_t30.csv',
#  'tk_sk&ld_sptn_t31.csv',
#  'tk_sk&ld_sptn_t32.csv',
#  'tk_sk&ld_sptn_t33.csv',
#  'tk_sk&ld_sptn_t34.csv',
#  'tk_sk&ld_sptn_t35.csv',
#  'tk_sk&ld_sptn_t36.csv',
#  'tk_sk&ld_sptn_t37.csv',
#  'tk_sk&ld_sptn_t38.csv',
#  'tk_sk&ld_sptn_t39.csv',
#  'tk_sk&ld_sptn_t4.csv',
#  'tk_sk&ld_sptn_t40.csv',
#  'tk_sk&ld_sptn_t41.csv',
#  'tk_sk&ld_sptn_t42.csv',
#  'tk_sk&ld_sptn_t43.csv',
#  'tk_sk&ld_sptn_t44.csv',
#  'tk_sk&ld_sptn_t45.csv',
#  'tk_sk&ld_sptn_t46.csv',
#  'tk_sk&ld_sptn_t47.csv',
#  'tk_sk&ld_sptn_t48.csv',
#  'tk_sk&ld_sptn_t49.csv',
#  'tk_sk&ld_sptn_t5.csv',
#  'tk_sk&ld_sptn_t50.csv',
#  'tk_sk&ld_sptn_t6.csv',
#  'tk_sk&ld_sptn_t7.csv',
#  'tk_sk&ld_sptn_t8.csv',
#  'tk_sk&ld_sptn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_sptn_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Dầu dừa ghee Viet healthy 1000ml, giàu vitamin...  439.000₫
# 1                   Tinh Dầu Tràm Gold Đặc Biệt 50 ml  150.000₫
# 2   Tinh Dầu Hoa Bưởi Homer 100ml - Chính Hãng, Đạ...  149.000₫
# 3   Nến Thơm Bánh Cupcake Phủ Kem Cherry Màu Pátel...   95.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       439000
# 1       150000
# 2       149000
# 3        95000
# 4       240000
#          ...
# 1636     95000
# 1637    230000
# 1638    265000
# 1639    195000
# 1640    136800
# Name: price, Length: 1641, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         4.0
# 1        25.0
# 2       210.0
# 3         1.0
# 4         2.0
#         ...
# 1636      2.0
# 1637     16.0
# 1638      3.0
# 1639      3.0
# 1640     55.0
# Name: sales, Length: 1641, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        1756000.0
# 1        3750000.0
# 2       31290000.0
# 3          95000.0
# 4         480000.0
#            ...
# 1636      190000.0
# 1637     3680000.0
# 1638      795000.0
# 1639      585000.0
# 1640     7524000.0
# Name: revenue, Length: 1641, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số sản phẩm tự nhiên: ", total)
# Out:
# Tổng doanh số sản phẩm tự nhiên:  39149491126.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Dầu dừa ghee Viet healthy 1000ml, giàu vitamin...  439000
# 1                     Tinh Dầu Tràm Gold Đặc Biệt 50 ml  150000
# 2     Tinh Dầu Hoa Bưởi Homer 100ml - Chính Hãng, Đạ...  149000
# 3     Nến Thơm Bánh Cupcake Phủ Kem Cherry Màu Pátel...   95000
# 4                                 Chiết xuất hương thảo  240000
# ...                                                 ...     ...
# 1636  máy khuếch tán tinh dầu lọ hoa lớn + Tặng tinh...   95000
# 1637                     Tinh Dầu Leviter Sá Xị (100ml)  230000
# 1638  Máy phun sương tạo ẩm xông tinh dầu Humidifier...  265000
# 1639  Tinh dầu Bạch Đàn Chanh 100ml nguyên chất từ t...  195000
# 1640  Phấn Trang Điểm Màu Trắng Phấn Nụ Hoàng Cung (...  136800
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/dau-dua-ghee-viet-healthy-1000...      NaN    4.0
# 1     https://tiki.vn/tinh-dau-tram-gold-dac-biet-50...     -47%   25.0
# 2     https://tiki.vn/tinh-dau-hoa-buoi-homer-100ml-...     -30%  210.0
# 3     https://tiki.vn/nen-thom-banh-cupcake-phu-kem-...      -5%    1.0
# 4     https://tiki.vn/chiet-xuat-huong-thao-p8438284...      -9%    2.0
# ...                                                 ...      ...    ...
# 1636  https://tiki.vn/may-khuech-tan-tinh-dau-lo-hoa...      NaN    2.0
# 1637  https://tiki.vn/tinh-dau-leviter-sa-xi-100ml-p...      NaN   16.0
# 1638  https://tiki.vn/may-phun-suong-tao-am-xong-tin...      NaN    3.0
# 1639  https://tiki.vn/tinh-dau-bach-dan-chanh-100ml-...      NaN    3.0
# 1640  https://tiki.vn/phan-trang-diem-mau-trang-phan...      NaN   55.0
#
#          revenue
# 0      1756000.0
# 1      3750000.0
# 2     31290000.0
# 3        95000.0
# 4       480000.0
# ...          ...
# 1636    190000.0
# 1637   3680000.0
# 1638    795000.0
# 1639    585000.0
# 1640   7524000.0
#
# [1641 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_sptn_all_ed.csv")
