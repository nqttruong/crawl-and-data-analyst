# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\td"
os.listdir(path)
# Out:
# ['tk_sk&ld_sptn_all.ipynb',
#  'tk_sk&ld_td_npage - Copy (3).ipynb',
#  'tk_sk&ld_td_t10.csv',
#  'tk_sk&ld_td_t11.csv',
#  'tk_sk&ld_td_t12.csv',
#  'tk_sk&ld_td_t13.csv',
#  'tk_sk&ld_td_t14.csv',
#  'tk_sk&ld_td_t15.csv',
#  'tk_sk&ld_td_t16.csv',
#  'tk_sk&ld_td_t17.csv',
#  'tk_sk&ld_td_t18.csv',
#  'tk_sk&ld_td_t19.csv',
#  'tk_sk&ld_td_t2.csv',
#  'tk_sk&ld_td_t20.csv',
#  'tk_sk&ld_td_t21.csv',
#  'tk_sk&ld_td_t22.csv',
#  'tk_sk&ld_td_t23.csv',
#  'tk_sk&ld_td_t24.csv',
#  'tk_sk&ld_td_t25.csv',
#  'tk_sk&ld_td_t26.csv',
#  'tk_sk&ld_td_t27.csv',
#  'tk_sk&ld_td_t28.csv',
#  'tk_sk&ld_td_t29.csv',
#  'tk_sk&ld_td_t3.csv',
#  'tk_sk&ld_td_t30.csv',
#  'tk_sk&ld_td_t31.csv',
#  'tk_sk&ld_td_t32.csv',
#  'tk_sk&ld_td_t33.csv',
#  'tk_sk&ld_td_t34.csv',
#  'tk_sk&ld_td_t35.csv',
#  'tk_sk&ld_td_t36.csv',
#  'tk_sk&ld_td_t37.csv',
#  'tk_sk&ld_td_t38.csv',
#  'tk_sk&ld_td_t39.csv',
#  'tk_sk&ld_td_t4.csv',
#  'tk_sk&ld_td_t40.csv',
#  'tk_sk&ld_td_t41.csv',
#  'tk_sk&ld_td_t42.csv',
#  'tk_sk&ld_td_t43.csv',
#  'tk_sk&ld_td_t44.csv',
#  'tk_sk&ld_td_t45.csv',
#  'tk_sk&ld_td_t46.csv',
#  'tk_sk&ld_td_t47.csv',
#  'tk_sk&ld_td_t48.csv',
#  'tk_sk&ld_td_t49.csv',
#  'tk_sk&ld_td_t5.csv',
#  'tk_sk&ld_td_t50.csv',
#  'tk_sk&ld_td_t6.csv',
#  'tk_sk&ld_td_t7.csv',
#  'tk_sk&ld_td_t8.csv',
#  'tk_sk&ld_td_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_td_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Kéo Cắt Chân Mày Thép Không Gỉ Inox Kềm Nghĩa ...   59.800₫
# 1   Chì kẻ viền môi Mira Auto Lipliner Hàn Quốc No...   95.000₫
# 2                       Phấn mắt FOCALLURE 10 màu 10g   75.000₫
# 3   Phấn nước BB với bông phấn đầu nấm SUNISA độc ...   75.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Xịt khóa nền MAKEUP FIXER SPRAY giữ chặt lớp t...   39.000₫
# 37  Son Dưỡng Môi Coco Balmie Sense Plus hỗ trợ Tr...   89.000₫
# 38  Kẻ mắt nước Mira Aroma Liquid Eyeliner Hàn Quố...  155.000₫
# 39  (BẢN MỚI) Chì Kẻ Viền Môi Vacosi Lipliner Penc...   46.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0         59800
# 1         95000
# 2         75000
# 3         75000
# 4       2300000
#          ...
# 1624     165000
# 1625      39000
# 1626      89000
# 1627     155000
# 1628      46000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       249.0
# 1        48.0
# 2         2.0
# 3       352.0
# 4         1.0
#         ...
# 1624      6.0
# 1625      2.0
# 1626    283.0
# 1627     83.0
# 1628     26.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       14890200.0
# 1        4560000.0
# 2         150000.0
# 3       26400000.0
# 4        2300000.0
#            ...
# 1624      990000.0
# 1625       78000.0
# 1626    25187000.0
# 1627    12865000.0
# 1628     1196000.0
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số trang điểm: ", total)
# Out:
# Tổng doanh số trang điểm:  14345588865.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Kéo Cắt Chân Mày Thép Không Gỉ Inox Kềm Nghĩa ...    59800
# 1     Chì kẻ viền môi Mira Auto Lipliner Hàn Quốc No...    95000
# 2                         Phấn mắt FOCALLURE 10 màu 10g    75000
# 3     Phấn nước BB với bông phấn đầu nấm SUNISA độc ...    75000
# 4     Phấn nước hoàng cung cao cấp Whoo Radiant Esse...  2300000
# ...                                                 ...      ...
# 1624  Kem dưỡng ẩm sáng và mềm da VNVN Rejuvenating ...   165000
# 1625  Xịt khóa nền MAKEUP FIXER SPRAY giữ chặt lớp t...    39000
# 1626  Son Dưỡng Môi Coco Balmie Sense Plus hỗ trợ Tr...    89000
# 1627  Kẻ mắt nước Mira Aroma Liquid Eyeliner Hàn Quố...   155000
# 1628  (BẢN MỚI) Chì Kẻ Viền Môi Vacosi Lipliner Penc...    46000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/keo-ca-nhan-thep-khong-gi-km-6...      -8%  249.0
# 1     https://tiki.vn/chi-ke-vien-moi-mira-auto-lipl...      -5%   48.0
# 2     https://tiki.vn/phan-mat-focallure-10-mau-10g-...     -40%    2.0
# 3     https://tiki.vn/phan-nuoc-bb-voi-bong-phan-dau...     -43%  352.0
# 4     https://tiki.vn/phan-nuoc-hoang-cung-cao-cap-w...      NaN    1.0
# ...                                                 ...      ...    ...
# 1624  https://tiki.vn/kem-duong-am-sang-va-mem-da-vn...      NaN    6.0
# 1625  https://tiki.vn/xit-khoa-nen-makeup-fixer-spra...      NaN    2.0
# 1626  https://tiki.vn/son-duong-moi-coco-balmie-sens...      NaN  283.0
# 1627  https://tiki.vn/ke-mat-nuoc-mira-aroma-liquid-...      NaN   83.0
# 1628  https://tiki.vn/ban-moi-chi-ke-vien-moi-vacosi...      NaN   26.0
#
#          revenue
# 0     14890200.0
# 1      4560000.0
# 2       150000.0
# 3     26400000.0
# 4      2300000.0
# ...          ...
# 1624    990000.0
# 1625     78000.0
# 1626  25187000.0
# 1627  12865000.0
# 1628   1196000.0
#
# [1629 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_td_all_ed.csv")
