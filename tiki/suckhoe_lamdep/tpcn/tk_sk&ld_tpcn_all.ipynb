# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\tpcn"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_tpcn_all.ipynb',
#  'tk_sk&ld_tpcn_npage - Copy (11).ipynb',
#  'tk_sk&ld_tpcn_t10.csv',
#  'tk_sk&ld_tpcn_t11.csv',
#  'tk_sk&ld_tpcn_t12.csv',
#  'tk_sk&ld_tpcn_t13.csv',
#  'tk_sk&ld_tpcn_t14.csv',
#  'tk_sk&ld_tpcn_t15.csv',
#  'tk_sk&ld_tpcn_t16.csv',
#  'tk_sk&ld_tpcn_t17.csv',
#  'tk_sk&ld_tpcn_t18.csv',
#  'tk_sk&ld_tpcn_t19.csv',
#  'tk_sk&ld_tpcn_t2.csv',
#  'tk_sk&ld_tpcn_t20.csv',
#  'tk_sk&ld_tpcn_t21.csv',
#  'tk_sk&ld_tpcn_t22.csv',
#  'tk_sk&ld_tpcn_t23.csv',
#  'tk_sk&ld_tpcn_t24.csv',
#  'tk_sk&ld_tpcn_t25.csv',
#  'tk_sk&ld_tpcn_t26.csv',
#  'tk_sk&ld_tpcn_t27.csv',
#  'tk_sk&ld_tpcn_t28.csv',
#  'tk_sk&ld_tpcn_t29.csv',
#  'tk_sk&ld_tpcn_t3.csv',
#  'tk_sk&ld_tpcn_t30.csv',
#  'tk_sk&ld_tpcn_t31.csv',
#  'tk_sk&ld_tpcn_t32.csv',
#  'tk_sk&ld_tpcn_t33.csv',
#  'tk_sk&ld_tpcn_t34.csv',
#  'tk_sk&ld_tpcn_t35.csv',
#  'tk_sk&ld_tpcn_t36.csv',
#  'tk_sk&ld_tpcn_t37.csv',
#  'tk_sk&ld_tpcn_t38.csv',
#  'tk_sk&ld_tpcn_t39.csv',
#  'tk_sk&ld_tpcn_t4.csv',
#  'tk_sk&ld_tpcn_t40.csv',
#  'tk_sk&ld_tpcn_t41.csv',
#  'tk_sk&ld_tpcn_t42.csv',
#  'tk_sk&ld_tpcn_t43.csv',
#  'tk_sk&ld_tpcn_t44.csv',
#  'tk_sk&ld_tpcn_t45.csv',
#  'tk_sk&ld_tpcn_t46.csv',
#  'tk_sk&ld_tpcn_t47.csv',
#  'tk_sk&ld_tpcn_t48.csv',
#  'tk_sk&ld_tpcn_t49.csv',
#  'tk_sk&ld_tpcn_t5.csv',
#  'tk_sk&ld_tpcn_t50.csv',
#  'tk_sk&ld_tpcn_t6.csv',
#  'tk_sk&ld_tpcn_t7.csv',
#  'tk_sk&ld_tpcn_t8.csv',
#  'tk_sk&ld_tpcn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_tpcn_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Combo 2 hộp ANGELA GOLD tăng cường sinh lý nữ ...  1.440.000₫
# 1   Canxi cho người lớn Kirkland Calcium thêm: Man...    598.000₫
# 2   Thiên Môn Bổ Phổi Bình Đông – Giúp giảm ho, Bổ...     74.000₫
# 3          Viên uống Làm Đẹp Da DHC Collagen Nhật Bản    165.000₫
# 4   Thực Phẩm Chức Năng Tinh Hàu Biển OB - Tăng Cư...    328.000₫
# ..                                                ...         ...
# 35  Đại Hoàng PQA Hỗ Trợ Nhuận Tràng, Thông Tiện, ...    187.000₫
# 36  Combo 3 Viên Uống + 1 Kem Hỗ Trợ Làm Giảm Và P...    781.000₫
# 37  Mật ong nguyên chất hoa rừng tự nhiên Quê Việt...    140.000₫
# 38  [Kolmar]Thực phẩm bảo vệ sức khỏe hộp 10 chai ...    270.000₫
# 39  Thực phẩm chức năng Cao hồng sâm Kanghwa Hàn Q...  1.234.800₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1440000
# 1        598000
# 2         74000
# 3        165000
# 4        328000
#          ...
# 1970     187000
# 1971     781000
# 1972     140000
# 1973     270000
# 1974    1234800
# Name: price, Length: 1975, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        282.0
# 1        144.0
# 2       2300.0
# 3        740.0
# 4        886.0
#          ...
# 1970      11.0
# 1971       7.0
# 1972      19.0
# 1973       1.0
# 1974       NaN
# Name: sales, Length: 1975, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       406080000.0
# 1        86112000.0
# 2       170200000.0
# 3       122100000.0
# 4       290608000.0
#            ...
# 1970      2057000.0
# 1971      5467000.0
# 1972      2660000.0
# 1973       270000.0
# 1974            NaN
# Name: revenue, Length: 1975, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thực phẩm chức năng: ", total)
# Out:
# Tổng doanh số thực phẩm chức năng:  87955028796.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Combo 2 hộp ANGELA GOLD tăng cường sinh lý nữ ...  1440000
# 1     Canxi cho người lớn Kirkland Calcium thêm: Man...   598000
# 2     Thiên Môn Bổ Phổi Bình Đông – Giúp giảm ho, Bổ...    74000
# 3            Viên uống Làm Đẹp Da DHC Collagen Nhật Bản   165000
# 4     Thực Phẩm Chức Năng Tinh Hàu Biển OB - Tăng Cư...   328000
# ...                                                 ...      ...
# 1970  Đại Hoàng PQA Hỗ Trợ Nhuận Tràng, Thông Tiện, ...   187000
# 1971  Combo 3 Viên Uống + 1 Kem Hỗ Trợ Làm Giảm Và P...   781000
# 1972  Mật ong nguyên chất hoa rừng tự nhiên Quê Việt...   140000
# 1973  [Kolmar]Thực phẩm bảo vệ sức khỏe hộp 10 chai ...   270000
# 1974  Thực phẩm chức năng Cao hồng sâm Kanghwa Hàn Q...  1234800
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/combo-2-chai-60-vien-tang-chai...     -12%   282.0
# 1     https://tiki.vn/canxi-cho-nguoi-lon-kirkland-s...     -15%   144.0
# 2     https://tiki.vn/thuc-pham-chuc-nang-thien-mon-...     -13%  2300.0
# 3     https://tiki.vn/vien-uong-lam-dep-da-dhc-colla...     -10%   740.0
# 4     https://tiki.vn/thuc-pham-chuc-nang-tinh-hau-b...     -14%   886.0
# ...                                                 ...      ...     ...
# 1970  https://tiki.vn/dai-hoang-pqa-ho-tro-nhuan-tra...      NaN    11.0
# 1971  https://tiki.vn/combo-3-vien-uong-1-kem-ho-tro...      NaN     7.0
# 1972  https://tiki.vn/mat-ong-nguyen-chat-hoa-rung-t...      NaN    19.0
# 1973  https://tiki.vn/kolmar-thuc-pham-bao-ve-suc-kh...      NaN     1.0
# 1974  https://tiki.vn/thuc-pham-chuc-nang-cao-hong-s...      NaN     NaN
#
#           revenue
# 0     406080000.0
# 1      86112000.0
# 2     170200000.0
# 3     122100000.0
# 4     290608000.0
# ...           ...
# 1970    2057000.0
# 1971    5467000.0
# 1972    2660000.0
# 1973     270000.0
# 1974          NaN
#
# [1975 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_tpcn_all_ed.csv")
