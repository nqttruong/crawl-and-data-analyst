# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\suckhoe_lamdep\csct"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_sk&ld_csct_all.ipynb',
#  'tk_sk&ld_csct_npage - Copy (5).ipynb',
#  'tk_sk&ld_csct_t10.csv',
#  'tk_sk&ld_csct_t11.csv',
#  'tk_sk&ld_csct_t12.csv',
#  'tk_sk&ld_csct_t13.csv',
#  'tk_sk&ld_csct_t14.csv',
#  'tk_sk&ld_csct_t15.csv',
#  'tk_sk&ld_csct_t16.csv',
#  'tk_sk&ld_csct_t17.csv',
#  'tk_sk&ld_csct_t18.csv',
#  'tk_sk&ld_csct_t19.csv',
#  'tk_sk&ld_csct_t2.csv',
#  'tk_sk&ld_csct_t20.csv',
#  'tk_sk&ld_csct_t21.csv',
#  'tk_sk&ld_csct_t22.csv',
#  'tk_sk&ld_csct_t23.csv',
#  'tk_sk&ld_csct_t24.csv',
#  'tk_sk&ld_csct_t25.csv',
#  'tk_sk&ld_csct_t26.csv',
#  'tk_sk&ld_csct_t27.csv',
#  'tk_sk&ld_csct_t28.csv',
#  'tk_sk&ld_csct_t29.csv',
#  'tk_sk&ld_csct_t3.csv',
#  'tk_sk&ld_csct_t30.csv',
#  'tk_sk&ld_csct_t31.csv',
#  'tk_sk&ld_csct_t32.csv',
#  'tk_sk&ld_csct_t33.csv',
#  'tk_sk&ld_csct_t34.csv',
#  'tk_sk&ld_csct_t35.csv',
#  'tk_sk&ld_csct_t36.csv',
#  'tk_sk&ld_csct_t37.csv',
#  'tk_sk&ld_csct_t38.csv',
#  'tk_sk&ld_csct_t39.csv',
#  'tk_sk&ld_csct_t4.csv',
#  'tk_sk&ld_csct_t40.csv',
#  'tk_sk&ld_csct_t41.csv',
#  'tk_sk&ld_csct_t42.csv',
#  'tk_sk&ld_csct_t43.csv',
#  'tk_sk&ld_csct_t44.csv',
#  'tk_sk&ld_csct_t45.csv',
#  'tk_sk&ld_csct_t46.csv',
#  'tk_sk&ld_csct_t47.csv',
#  'tk_sk&ld_csct_t48.csv',
#  'tk_sk&ld_csct_t49.csv',
#  'tk_sk&ld_csct_t5.csv',
#  'tk_sk&ld_csct_t50.csv',
#  'tk_sk&ld_csct_t6.csv',
#  'tk_sk&ld_csct_t7.csv',
#  'tk_sk&ld_csct_t8.csv',
#  'tk_sk&ld_csct_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_sk&ld_csct_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Sữa Tắm Dành Cho Da Nhạy Cảm Eucerin pH5 1000m...  474.000₫
# 1   Kem DưỡngTrắng Da Toàn Thân Body Collagen X3 L...   35.000₫
# 2   SỮA TẮM DETTOL ONZEN DƯỠNG ẨM LÔ HỘI & BƠ 950G...  137.000₫
# 3   Sữa tắm dành cho da nhạy cảm Eucerin pH5 Washl...  373.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Sữa Tắm Gội Coast Classic Scent Dành Cho Nam 9...  185.000₫
# 37  COMBO 2 SỮA TẮM DETTOL ONZEN DƯỠNG ẨM LÔ HỘ
rows x 5 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       474000
# 1        35000
# 2       137000
# 3       373000
# 4       285000
#          ...
# 1624    422000
# 1625    185000
# 1626    270000
# 1627    200000
# 1628    106000
# Name: price, Length: 1629, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        232.0
# 1         36.0
# 2          7.0
# 3        124.0
# 4         21.0
#          ...
# 1624     181.0
# 1625     163.0
# 1626      10.0
# 1627     406.0
# 1628    1100.0
# Name: sales, Length: 1629, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       109968000.0
# 1         1260000.0
# 2          959000.0
# 3        46252000.0
# 4         5985000.0
#            ...
# 1624     76382000.0
# 1625     30155000.0
# 1626      2700000.0
# 1627     81200000.0
# 1628    116600000.0
# Name: revenue, Length: 1629, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chăm sóc cơ thể: ", total)
# Out:
# Tổng doanh số chăm sóc cơ thể:  55770441542.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Sữa Tắm Dành Cho Da Nhạy Cảm Eucerin pH5 1000m...  474000
# 1     Kem DưỡngTrắng Da Toàn Thân Body Collagen X3 L...   35000
# 2     SỮA TẮM DETTOL ONZEN DƯỠNG ẨM LÔ HỘI & BƠ 950G...  137000
# 3     Sữa tắm dành cho da nhạy cảm Eucerin pH5 Washl...  373000
# 4     Kem chống nắng nâng tông da CNP Laboratory Ton...  285000
# ...                                                 ...     ...
# 1624  Sữa tắm dưỡng ẩm cho viêm da cơ địa Cetaphil P...  422000
# 1625  Sữa Tắm Gội Coast Classic Scent Dành Cho Nam 9...  185000
# 1626  COMBO 2 SỮA TẮM DETTOL ONZEN DƯỠNG ẨM LÔ HỘI &...  270000
# 1627  Combo 2 Xịt Ngăn Mùi NIVEA Pearl & Beauty Ngọc...  200000
# 1628  Combo 2 Lăn khử mùi Romano kháng khuẩn & khô t...  106000
#
#                                               link_item discount   sales  \
# 0     https://tiki.vn/sua-tam-danh-cho-da-nhay-cam-e...     -29%   232.0
# 1     https://tiki.vn/kem-duongtrang-da-toan-than-bo...     -23%    36.0
# 2     https://tiki.vn/sua-tam-dettol-onzen-duong-am-...     -25%     7.0
# 3     https://tiki.vn/sua-tam-danh-cho-da-nhay-cam-e...      NaN   124.0
# 4     https://tiki.vn/kem-chong-nang-nang-tong-da-cn...     -47%    21.0
# ...                                                 ...      ...     ...
# 1624  https://tiki.vn/sua-tam-duong-am-cho-viem-da-c...      NaN   181.0
# 1625  https://tiki.vn/sua-tam-goi-coast-classic-scen...      NaN   163.0
# 1626  https://tiki.vn/combo-2-sua-tam-dettol-onzen-d...      NaN    10.0
# 1627  https://tiki.vn/combo-2-xit-ngan-mui-nivea-pea...      NaN   406.0
# 1628  https://tiki.vn/combo-2-lan-khu-mui-romano-kha...      NaN  1100.0
#
#           revenue
# 0     109968000.0
# 1       1260000.0
# 2        959000.0
# 3      46252000.0
# 4       5985000.0
# ...           ...
# 1624   76382000.0
# 1625   30155000.0
# 1626    2700000.0
# 1627   81200000.0
# 1628  116600000.0
#
# [1629 rows x 6 columns]

# %%
df_all.to_csv("tk_sk&ld_csct_all_ed.csv")
